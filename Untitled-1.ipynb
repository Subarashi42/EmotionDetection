# %%
# !python3 -m pip install --upgrade pip
# !pip3 install tensorflow
# !pip3 install opencv-python
# !pip3 install requests
# !pip3 install matplotlib
# !pip3 install scikit-learn
# !pip3 install pandas
# !pip3 install seaborn
# !pip3 install keras
# !pip3 install mediaPipe
# !pip3 install mediapipe
# !pip3 install numpy 
# !pip3 install scipy
# !pip3 install scikit-image
# !pip3 install pillow
# !pip3 install imutils
# !pip3 install pytube
# !pip3 install moviepy
# !pip3 install pytube3
# !pip3 install pytubeX
# !pip3 install pytubeX
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: pip in /Users/aiden/Library/Python/3.9/lib/python/site-packages (25.0.1)
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: tensorflow in /Users/aiden/Library/Python/3.9/lib/python/site-packages (2.19.0)
# Requirement already satisfied: absl-py>=1.0.0 in /Users/aiden/Library/Python/3.9/lib/python/site-packages (from tensorflow) (2.2.1)
# Requirement already satisfied: astunparse>=1.6.0 in /Users/aiden/Library/Python/3.9/lib/python/site-packages (from tensorflow) (1.6.3)
# Requirement already satisfied: flatbuffers>=24.3.25 in /Users/aiden/Library/Python/3.9/lib/python/site-packages (from tensorflow) (25.2.10)
# Requirement already satisfied: gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1 in /Users/aiden/Library/Python/3.9/lib/python/site-packages (from tensorflow) (0.6.0)
# Requirement already satisfied: google-pasta>=0.1.1 in /Users/aiden/Library/Python/3.9/lib/python/site-packages (from tensorflow) (0.2.0)
# Requirement already satisfied: libclang>=13.0.0 in /Users/aiden/Library/Python/3.9/lib/python/site-packages (from tensorflow) (18.1.1)
# Requirement already satisfied: opt-einsum>=2.3.2 in /Users/aiden/Library/Python/3.9/lib/python/site-packages (from tensorflow) (3.4.0)
# Requirement already satisfied: packaging in /Users/aiden/Library/Python/3.9/lib/python/site-packages (from tensorflow) (23.2)
# Requirement already satisfied: protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<6.0.0dev,>=3.20.3 in /Users/aiden/Library/Python/3.9/lib/python/site-packages (from tensorflow) (3.20.3)
# Requirement already satisfied: requests<3,>=2.21.0 in /Users/aiden/Library/Python/3.9/lib/python/site-packages (from tensorflow) (2.32.3)
# Requirement already satisfied: setuptools in /Library/Developer/CommandLineTools/Library/Frameworks/Python3.framework/Versions/3.9/lib/python3.9/site-packages (from tensorflow) (58.0.4)
# Requirement already satisfied: six>=1.12.0 in /Users/aiden/Library/Python/3.9/lib/python/site-packages (from tensorflow) (1.17.0)
# Requirement already satisfied: termcolor>=1.1.0 in /Users/aiden/Library/Python/3.9/lib/python/site-packages (from tensorflow) (2.5.0)
# Requirement already satisfied: typing-extensions>=3.6.6 in /Users/aiden/Library/Python/3.9/lib/python/site-packages (from tensorflow) (4.12.2)
# Requirement already satisfied: wrapt>=1.11.0 in /Users/aiden/Library/Python/3.9/lib/python/site-packages (from tensorflow) (1.17.2)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in /Users/aiden/Library/Python/3.9/lib/python/site-packages (from tensorflow) (1.71.0)
# Requirement already satisfied: tensorboard~=2.19.0 in /Users/aiden/Library/Python/3.9/lib/python/site-packages (from tensorflow) (2.19.0)
# Requirement already satisfied: keras>=3.5.0 in /Users/aiden/Library/Python/3.9/lib/python/site-packages (from tensorflow) (3.9.1)
# Requirement already satisfied: numpy<2.2.0,>=1.26.0 in /Users/aiden/Library/Python/3.9/lib/python/site-packages (from tensorflow) (2.0.2)
# Requirement already satisfied: h5py>=3.11.0 in /Users/aiden/Library/Python/3.9/lib/python/site-packages (from tensorflow) (3.13.0)
# Requirement already satisfied: ml-dtypes<1.0.0,>=0.5.1 in /Users/aiden/Library/Python/3.9/lib/python/site-packages (from tensorflow) (0.5.1)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in /Users/aiden/Library/Python/3.9/lib/python/site-packages (from tensorflow) (0.37.1)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in /Library/Developer/CommandLineTools/Library/Frameworks/Python3.framework/Versions/3.9/lib/python3.9/site-packages (from astunparse>=1.6.0->tensorflow) (0.37.0)
# Requirement already satisfied: rich in /Users/aiden/Library/Python/3.9/lib/python/site-packages (from keras>=3.5.0->tensorflow) (14.0.0)
# Requirement already satisfied: namex in /Users/aiden/Library/Python/3.9/lib/python/site-packages (from keras>=3.5.0->tensorflow) (0.0.8)
# Requirement already satisfied: optree in /Users/aiden/Library/Python/3.9/lib/python/site-packages (from keras>=3.5.0->tensorflow) (0.14.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /Users/aiden/Library/Python/3.9/lib/python/site-packages (from requests<3,>=2.21.0->tensorflow) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in /Users/aiden/Library/Python/3.9/lib/python/site-packages (from requests<3,>=2.21.0->tensorflow) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/aiden/Library/Python/3.9/lib/python/site-packages (from requests<3,>=2.21.0->tensorflow) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/aiden/Library/Python/3.9/lib/python/site-packages (from requests<3,>=2.21.0->tensorflow) (2025.1.31)
# Requirement already satisfied: markdown>=2.6.8 in /Users/aiden/Library/Python/3.9/lib/python/site-packages (from tensorboard~=2.19.0->tensorflow) (3.7)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in /Users/aiden/Library/Python/3.9/lib/python/site-packages (from tensorboard~=2.19.0->tensorflow) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in /Users/aiden/Library/Python/3.9/lib/python/site-packages (from tensorboard~=2.19.0->tensorflow) (3.1.3)
# Requirement already satisfied: importlib-metadata>=4.4 in /Users/aiden/Library/Python/3.9/lib/python/site-packages (from markdown>=2.6.8->tensorboard~=2.19.0->tensorflow) (8.6.1)
# Requirement already satisfied: MarkupSafe>=2.1.1 in /Users/aiden/Library/Python/3.9/lib/python/site-packages (from werkzeug>=1.0.1->tensorboard~=2.19.0->tensorflow) (3.0.2)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /Users/aiden/Library/Python/3.9/lib/python/site-packages (from rich->keras>=3.5.0->tensorflow) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /Users/aiden/Library/Python/3.9/lib/python/site-packages (from rich->keras>=3.5.0->tensorflow) (2.19.1)
# Requirement already satisfied: zipp>=3.20 in /Users/aiden/Library/Python/3.9/lib/python/site-packages (from importlib-metadata>=4.4->markdown>=2.6.8->tensorboard~=2.19.0->tensorflow) (3.21.0)
# Requirement already satisfied: mdurl~=0.1 in /Users/aiden/Library/Python/3.9/lib/python/site-packages (from markdown-it-py>=2.2.0->rich->keras>=3.5.0->tensorflow) (0.1.2)
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: opencv-python in /Users/aiden/Library/Python/3.9/lib/python/site-packages (4.11.0.86)
# Requirement already satisfied: numpy>=1.21.0 in /Users/aiden/Library/Python/3.9/lib/python/site-packages (from opencv-python) (2.0.2)
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: requests in /Users/aiden/Library/Python/3.9/lib/python/site-packages (2.32.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in /Users/aiden/Library/Python/3.9/lib/python/site-packages (from requests) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in /Users/aiden/Library/Python/3.9/lib/python/site-packages (from requests) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/aiden/Library/Python/3.9/lib/python/site-packages (from requests) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/aiden/Library/Python/3.9/lib/python/site-packages (from requests) (2025.1.31)
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: matplotlib in /Users/aiden/Library/Python/3.9/lib/python/site-packages (3.9.4)
# Requirement already satisfied: contourpy>=1.0.1 in /Users/aiden/Library/Python/3.9/lib/python/site-packages (from matplotlib) (1.3.0)
# Requirement already satisfied: cycler>=0.10 in /Users/aiden/Library/Python/3.9/lib/python/site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /Users/aiden/Library/Python/3.9/lib/python/site-packages (from matplotlib) (4.56.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /Users/aiden/Library/Python/3.9/lib/python/site-packages (from matplotlib) (1.4.7)
# Requirement already satisfied: numpy>=1.23 in /Users/aiden/Library/Python/3.9/lib/python/site-packages (from matplotlib) (2.0.2)
# Requirement already satisfied: packaging>=20.0 in /Users/aiden/Library/Python/3.9/lib/python/site-packages (from matplotlib) (23.2)
# Requirement already satisfied: pillow>=8 in /Users/aiden/Library/Python/3.9/lib/python/site-packages (from matplotlib) (11.1.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /Users/aiden/Library/Python/3.9/lib/python/site-packages (from matplotlib) (3.2.1)
# Requirement already satisfied: python-dateutil>=2.7 in /Users/aiden/Library/Python/3.9/lib/python/site-packages (from matplotlib) (2.9.0.post0)
# Requirement already satisfied: importlib-resources>=3.2.0 in /Users/aiden/Library/Python/3.9/lib/python/site-packages (from matplotlib) (6.5.2)
# Requirement already satisfied: zipp>=3.1.0 in /Users/aiden/Library/Python/3.9/lib/python/site-packages (from importlib-resources>=3.2.0->matplotlib) (3.21.0)
# Requirement already satisfied: six>=1.5 in /Users/aiden/Library/Python/3.9/lib/python/site-packages (from python-dateutil>=2.7->matplotlib) (1.17.0)
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: scikit-learn in /Users/aiden/Library/Python/3.9/lib/python/site-packages (1.6.1)
# Requirement already satisfied: numpy>=1.19.5 in /Users/aiden/Library/Python/3.9/lib/python/site-packages (from scikit-learn) (2.0.2)
# Requirement already satisfied: scipy>=1.6.0 in /Users/aiden/Library/Python/3.9/lib/python/site-packages (from scikit-learn) (1.13.1)
# Requirement already satisfied: joblib>=1.2.0 in /Users/aiden/Library/Python/3.9/lib/python/site-packages (from scikit-learn) (1.4.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /Users/aiden/Library/Python/3.9/lib/python/site-packages (from scikit-learn) (3.5.0)
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: pandas in /Users/aiden/Library/Python/3.9/lib/python/site-packages (2.2.3)
# Requirement already satisfied: numpy>=1.22.4 in /Users/aiden/Library/Python/3.9/lib/python/site-packages (from pandas) (2.0.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in /Users/aiden/Library/Python/3.9/lib/python/site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /Users/aiden/Library/Python/3.9/lib/python/site-packages (from pandas) (2025.1)
# Requirement already satisfied: tzdata>=2022.7 in /Users/aiden/Library/Python/3.9/lib/python/site-packages (from pandas) (2025.1)
# Requirement already satisfied: six>=1.5 in /Users/aiden/Library/Python/3.9/lib/python/site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: seaborn in /Users/aiden/Library/Python/3.9/lib/python/site-packages (0.13.2)
# Requirement already satisfied: numpy!=1.24.0,>=1.20 in /Users/aiden/Library/Python/3.9/lib/python/site-packages (from seaborn) (2.0.2)
# Requirement already satisfied: pandas>=1.2 in /Users/aiden/Library/Python/3.9/lib/python/site-packages (from seaborn) (2.2.3)
# Requirement already satisfied: matplotlib!=3.6.1,>=3.4 in /Users/aiden/Library/Python/3.9/lib/python/site-packages (from seaborn) (3.9.4)
# Requirement already satisfied: contourpy>=1.0.1 in /Users/aiden/Library/Python/3.9/lib/python/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (1.3.0)
# Requirement already satisfied: cycler>=0.10 in /Users/aiden/Library/Python/3.9/lib/python/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /Users/aiden/Library/Python/3.9/lib/python/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (4.56.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /Users/aiden/Library/Python/3.9/lib/python/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (1.4.7)
# Requirement already satisfied: packaging>=20.0 in /Users/aiden/Library/Python/3.9/lib/python/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (23.2)
# Requirement already satisfied: pillow>=8 in /Users/aiden/Library/Python/3.9/lib/python/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (11.1.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /Users/aiden/Library/Python/3.9/lib/python/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (3.2.1)
# Requirement already satisfied: python-dateutil>=2.7 in /Users/aiden/Library/Python/3.9/lib/python/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (2.9.0.post0)
# Requirement already satisfied: importlib-resources>=3.2.0 in /Users/aiden/Library/Python/3.9/lib/python/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (6.5.2)
# Requirement already satisfied: pytz>=2020.1 in /Users/aiden/Library/Python/3.9/lib/python/site-packages (from pandas>=1.2->seaborn) (2025.1)
# Requirement already satisfied: tzdata>=2022.7 in /Users/aiden/Library/Python/3.9/lib/python/site-packages (from pandas>=1.2->seaborn) (2025.1)
# Requirement already satisfied: zipp>=3.1.0 in /Users/aiden/Library/Python/3.9/lib/python/site-packages (from importlib-resources>=3.2.0->matplotlib!=3.6.1,>=3.4->seaborn) (3.21.0)
# Requirement already satisfied: six>=1.5 in /Users/aiden/Library/Python/3.9/lib/python/site-packages (from python-dateutil>=2.7->matplotlib!=3.6.1,>=3.4->seaborn) (1.17.0)
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: keras in /Users/aiden/Library/Python/3.9/lib/python/site-packages (3.9.1)
# Requirement already satisfied: absl-py in /Users/aiden/Library/Python/3.9/lib/python/site-packages (from keras) (2.2.1)
# Requirement already satisfied: numpy in /Users/aiden/Library/Python/3.9/lib/python/site-packages (from keras) (2.0.2)
# Requirement already satisfied: rich in /Users/aiden/Library/Python/3.9/lib/python/site-packages (from keras) (14.0.0)
# Requirement already satisfied: namex in /Users/aiden/Library/Python/3.9/lib/python/site-packages (from keras) (0.0.8)
# Requirement already satisfied: h5py in /Users/aiden/Library/Python/3.9/lib/python/site-packages (from keras) (3.13.0)
# Requirement already satisfied: optree in /Users/aiden/Library/Python/3.9/lib/python/site-packages (from keras) (0.14.1)
# Requirement already satisfied: ml-dtypes in /Users/aiden/Library/Python/3.9/lib/python/site-packages (from keras) (0.5.1)
# Requirement already satisfied: packaging in /Users/aiden/Library/Python/3.9/lib/python/site-packages (from keras) (23.2)
# Requirement already satisfied: typing-extensions>=4.5.0 in /Users/aiden/Library/Python/3.9/lib/python/site-packages (from optree->keras) (4.12.2)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /Users/aiden/Library/Python/3.9/lib/python/site-packages (from rich->keras) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /Users/aiden/Library/Python/3.9/lib/python/site-packages (from rich->keras) (2.19.1)
# Requirement already satisfied: mdurl~=0.1 in /Users/aiden/Library/Python/3.9/lib/python/site-packages (from markdown-it-py>=2.2.0->rich->keras) (0.1.2)
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: mediaPipe in /Users/aiden/Library/Python/3.9/lib/python/site-packages (0.10.9)
# Requirement already satisfied: absl-py in /Users/aiden/Library/Python/3.9/lib/python/site-packages (from mediaPipe) (2.2.1)
# Requirement already satisfied: attrs>=19.1.0 in /Users/aiden/Library/Python/3.9/lib/python/site-packages (from mediaPipe) (25.3.0)
# Requirement already satisfied: flatbuffers>=2.0 in /Users/aiden/Library/Python/3.9/lib/python/site-packages (from mediaPipe) (25.2.10)
# Requirement already satisfied: matplotlib in /Users/aiden/Library/Python/3.9/lib/python/site-packages (from mediaPipe) (3.9.4)
# Requirement already satisfied: numpy in /Users/aiden/Library/Python/3.9/lib/python/site-packages (from mediaPipe) (2.0.2)
# Requirement already satisfied: opencv-contrib-python in /Users/aiden/Library/Python/3.9/lib/python/site-packages (from mediaPipe) (4.11.0.86)
# Requirement already satisfied: protobuf<4,>=3.11 in /Users/aiden/Library/Python/3.9/lib/python/site-packages (from mediaPipe) (3.20.3)
# Requirement already satisfied: sounddevice>=0.4.4 in /Users/aiden/Library/Python/3.9/lib/python/site-packages (from mediaPipe) (0.5.1)
# Requirement already satisfied: CFFI>=1.0 in /Users/aiden/Library/Python/3.9/lib/python/site-packages (from sounddevice>=0.4.4->mediaPipe) (1.17.1)
# Requirement already satisfied: contourpy>=1.0.1 in /Users/aiden/Library/Python/3.9/lib/python/site-packages (from matplotlib->mediaPipe) (1.3.0)
# Requirement already satisfied: cycler>=0.10 in /Users/aiden/Library/Python/3.9/lib/python/site-packages (from matplotlib->mediaPipe) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /Users/aiden/Library/Python/3.9/lib/python/site-packages (from matplotlib->mediaPipe) (4.56.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /Users/aiden/Library/Python/3.9/lib/python/site-packages (from matplotlib->mediaPipe) (1.4.7)
# Requirement already satisfied: packaging>=20.0 in /Users/aiden/Library/Python/3.9/lib/python/site-packages (from matplotlib->mediaPipe) (23.2)
# Requirement already satisfied: pillow>=8 in /Users/aiden/Library/Python/3.9/lib/python/site-packages (from matplotlib->mediaPipe) (11.1.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /Users/aiden/Library/Python/3.9/lib/python/site-packages (from matplotlib->mediaPipe) (3.2.1)
# Requirement already satisfied: python-dateutil>=2.7 in /Users/aiden/Library/Python/3.9/lib/python/site-packages (from matplotlib->mediaPipe) (2.9.0.post0)
# Requirement already satisfied: importlib-resources>=3.2.0 in /Users/aiden/Library/Python/3.9/lib/python/site-packages (from matplotlib->mediaPipe) (6.5.2)
# Requirement already satisfied: pycparser in /Users/aiden/Library/Python/3.9/lib/python/site-packages (from CFFI>=1.0->sounddevice>=0.4.4->mediaPipe) (2.22)
# Requirement already satisfied: zipp>=3.1.0 in /Users/aiden/Library/Python/3.9/lib/python/site-packages (from importlib-resources>=3.2.0->matplotlib->mediaPipe) (3.21.0)
# Requirement already satisfied: six>=1.5 in /Users/aiden/Library/Python/3.9/lib/python/site-packages (from python-dateutil>=2.7->matplotlib->mediaPipe) (1.17.0)
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: mediapipe in /Users/aiden/Library/Python/3.9/lib/python/site-packages (0.10.9)
# Requirement already satisfied: absl-py in /Users/aiden/Library/Python/3.9/lib/python/site-packages (from mediapipe) (2.2.1)
# Requirement already satisfied: attrs>=19.1.0 in /Users/aiden/Library/Python/3.9/lib/python/site-packages (from mediapipe) (25.3.0)
# Requirement already satisfied: flatbuffers>=2.0 in /Users/aiden/Library/Python/3.9/lib/python/site-packages (from mediapipe) (25.2.10)
# Requirement already satisfied: matplotlib in /Users/aiden/Library/Python/3.9/lib/python/site-packages (from mediapipe) (3.9.4)
# Requirement already satisfied: numpy in /Users/aiden/Library/Python/3.9/lib/python/site-packages (from mediapipe) (2.0.2)
# Requirement already satisfied: opencv-contrib-python in /Users/aiden/Library/Python/3.9/lib/python/site-packages (from mediapipe) (4.11.0.86)
# Requirement already satisfied: protobuf<4,>=3.11 in /Users/aiden/Library/Python/3.9/lib/python/site-packages (from mediapipe) (3.20.3)
# Requirement already satisfied: sounddevice>=0.4.4 in /Users/aiden/Library/Python/3.9/lib/python/site-packages (from mediapipe) (0.5.1)
# Requirement already satisfied: CFFI>=1.0 in /Users/aiden/Library/Python/3.9/lib/python/site-packages (from sounddevice>=0.4.4->mediapipe) (1.17.1)
# Requirement already satisfied: contourpy>=1.0.1 in /Users/aiden/Library/Python/3.9/lib/python/site-packages (from matplotlib->mediapipe) (1.3.0)
# Requirement already satisfied: cycler>=0.10 in /Users/aiden/Library/Python/3.9/lib/python/site-packages (from matplotlib->mediapipe) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /Users/aiden/Library/Python/3.9/lib/python/site-packages (from matplotlib->mediapipe) (4.56.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /Users/aiden/Library/Python/3.9/lib/python/site-packages (from matplotlib->mediapipe) (1.4.7)
# Requirement already satisfied: packaging>=20.0 in /Users/aiden/Library/Python/3.9/lib/python/site-packages (from matplotlib->mediapipe) (23.2)
# Requirement already satisfied: pillow>=8 in /Users/aiden/Library/Python/3.9/lib/python/site-packages (from matplotlib->mediapipe) (11.1.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /Users/aiden/Library/Python/3.9/lib/python/site-packages (from matplotlib->mediapipe) (3.2.1)
# Requirement already satisfied: python-dateutil>=2.7 in /Users/aiden/Library/Python/3.9/lib/python/site-packages (from matplotlib->mediapipe) (2.9.0.post0)
# Requirement already satisfied: importlib-resources>=3.2.0 in /Users/aiden/Library/Python/3.9/lib/python/site-packages (from matplotlib->mediapipe) (6.5.2)
# Requirement already satisfied: pycparser in /Users/aiden/Library/Python/3.9/lib/python/site-packages (from CFFI>=1.0->sounddevice>=0.4.4->mediapipe) (2.22)
# Requirement already satisfied: zipp>=3.1.0 in /Users/aiden/Library/Python/3.9/lib/python/site-packages (from importlib-resources>=3.2.0->matplotlib->mediapipe) (3.21.0)
# Requirement already satisfied: six>=1.5 in /Users/aiden/Library/Python/3.9/lib/python/site-packages (from python-dateutil>=2.7->matplotlib->mediapipe) (1.17.0)
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: numpy in /Users/aiden/Library/Python/3.9/lib/python/site-packages (2.0.2)
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: scipy in /Users/aiden/Library/Python/3.9/lib/python/site-packages (1.13.1)
# Requirement already satisfied: numpy<2.3,>=1.22.4 in /Users/aiden/Library/Python/3.9/lib/python/site-packages (from scipy) (2.0.2)
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: scikit-image in /Users/aiden/Library/Python/3.9/lib/python/site-packages (0.24.0)
# Requirement already satisfied: numpy>=1.23 in /Users/aiden/Library/Python/3.9/lib/python/site-packages (from scikit-image) (2.0.2)
# Requirement already satisfied: scipy>=1.9 in /Users/aiden/Library/Python/3.9/lib/python/site-packages (from scikit-image) (1.13.1)
# Requirement already satisfied: networkx>=2.8 in /Users/aiden/Library/Python/3.9/lib/python/site-packages (from scikit-image) (3.2.1)
# Requirement already satisfied: pillow>=9.1 in /Users/aiden/Library/Python/3.9/lib/python/site-packages (from scikit-image) (11.1.0)
# Requirement already satisfied: imageio>=2.33 in /Users/aiden/Library/Python/3.9/lib/python/site-packages (from scikit-image) (2.37.0)
# Requirement already satisfied: tifffile>=2022.8.12 in /Users/aiden/Library/Python/3.9/lib/python/site-packages (from scikit-image) (2024.8.30)
# Requirement already satisfied: packaging>=21 in /Users/aiden/Library/Python/3.9/lib/python/site-packages (from scikit-image) (23.2)
# Requirement already satisfied: lazy-loader>=0.4 in /Users/aiden/Library/Python/3.9/lib/python/site-packages (from scikit-image) (0.4)
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: pillow in /Users/aiden/Library/Python/3.9/lib/python/site-packages (11.1.0)
# Defaulting to user installation because normal site-packages is not writeable
# Collecting imutils
#   Downloading imutils-0.5.4.tar.gz (17 kB)
#   Preparing metadata (setup.py) ... done
# Building wheels for collected packages: imutils
#   Building wheel for imutils (setup.py) ... done
#   Created wheel for imutils: filename=imutils-0.5.4-py3-none-any.whl size=25860 sha256=42369bd013d72266af9ca631d29e98aa573e2bd88933a56381cf56c39486ce84
#   Stored in directory: /Users/aiden/Library/Caches/pip/wheels/4b/a5/2d/4a070a801d3a3d93f033d3ee9728f470f514826e89952df3ea
# Successfully built imutils
# Installing collected packages: imutils
# Successfully installed imutils-0.5.4
# Defaulting to user installation because normal site-packages is not writeable
# Collecting pytube
#   Downloading pytube-15.0.0-py3-none-any.whl.metadata (5.0 kB)
# Downloading pytube-15.0.0-py3-none-any.whl (57 kB)
# Installing collected packages: pytube
# Successfully installed pytube-15.0.0
# Defaulting to user installation because normal site-packages is not writeable
# Collecting moviepy
#   Downloading moviepy-2.1.2-py3-none-any.whl.metadata (6.9 kB)
# Requirement already satisfied: decorator<6.0,>=4.0.2 in /Users/aiden/Library/Python/3.9/lib/python/site-packages (from moviepy) (5.1.1)
# Requirement already satisfied: imageio<3.0,>=2.5 in /Users/aiden/Library/Python/3.9/lib/python/site-packages (from moviepy) (2.37.0)
# Collecting imageio_ffmpeg>=0.2.0 (from moviepy)
#   Downloading imageio_ffmpeg-0.6.0-py3-none-macosx_11_0_arm64.whl.metadata (1.5 kB)
# Requirement already satisfied: numpy>=1.25.0 in /Users/aiden/Library/Python/3.9/lib/python/site-packages (from moviepy) (2.0.2)
# Collecting proglog<=1.0.0 (from moviepy)
#   Downloading proglog-0.1.11-py3-none-any.whl.metadata (794 bytes)
# Collecting python-dotenv>=0.10 (from moviepy)
#   Downloading python_dotenv-1.1.0-py3-none-any.whl.metadata (24 kB)
# Collecting pillow<11.0,>=9.2.0 (from moviepy)
#   Downloading pillow-10.4.0-cp39-cp39-macosx_11_0_arm64.whl.metadata (9.2 kB)
# Collecting tqdm (from proglog<=1.0.0->moviepy)
#   Using cached tqdm-4.67.1-py3-none-any.whl.metadata (57 kB)
# Downloading moviepy-2.1.2-py3-none-any.whl (126 kB)
# Downloading imageio_ffmpeg-0.6.0-py3-none-macosx_11_0_arm64.whl (21.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.1/21.1 MB 11.9 MB/s eta 0:00:00a 0:00:01
# Downloading pillow-10.4.0-cp39-cp39-macosx_11_0_arm64.whl (3.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.4/3.4 MB 11.9 MB/s eta 0:00:00a 0:00:01
# Downloading proglog-0.1.11-py3-none-any.whl (7.8 kB)
# Downloading python_dotenv-1.1.0-py3-none-any.whl (20 kB)
# Using cached tqdm-4.67.1-py3-none-any.whl (78 kB)
# Installing collected packages: tqdm, python-dotenv, pillow, imageio_ffmpeg, proglog, moviepy
#   Attempting uninstall: pillow
#     Found existing installation: pillow 11.1.0
#     Uninstalling pillow-11.1.0:
#       Successfully uninstalled pillow-11.1.0
# Successfully installed imageio_ffmpeg-0.6.0 moviepy-2.1.2 pillow-10.4.0 proglog-0.1.11 python-dotenv-1.1.0 tqdm-4.67.1
# Defaulting to user installation because normal site-packages is not writeable
# Collecting pytube3
#   Downloading pytube3-9.6.4-py3-none-any.whl.metadata (16 kB)
# Requirement already satisfied: typing-extensions in /Users/aiden/Library/Python/3.9/lib/python/site-packages (from pytube3) (4.12.2)
# Downloading pytube3-9.6.4-py3-none-any.whl (38 kB)
# Installing collected packages: pytube3
# Successfully installed pytube3-9.6.4
# Defaulting to user installation because normal site-packages is not writeable
# Collecting pytubeX
#   Downloading pytubeX-0.1.4.tar.gz (47 kB)
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: typing_extensions in /Users/aiden/Library/Python/3.9/lib/python/site-packages (from pytubeX) (4.12.2)
# Building wheels for collected packages: pytubeX
#   Building wheel for pytubeX (setup.py) ... done
#   Created wheel for pytubeX: filename=pytubeX-0.1.4-py3-none-any.whl size=38545 sha256=f54a89bbda23a9870cd8d63a86add3a1309fe442399e8a6ad261b0bd39f757ea
#   Stored in directory: /Users/aiden/Library/Caches/pip/wheels/66/c4/8c/e4196fbab0fc8e316368d19ebbf4971c60bb780ab3b6db39bf
# Successfully built pytubeX
# Installing collected packages: pytubeX
# Successfully installed pytubeX-0.1.4
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: pytubeX in /Users/aiden/Library/Python/3.9/lib/python/site-packages (0.1.4)
# Requirement already satisfied: typing-extensions in /Users/aiden/Library/Python/3.9/lib/python/site-packages (from pytubeX) (4.12.2)

# %%
import cv2
import os
import numpy as np
import mediapipe as mp
from tensorflow.keras.models import load_model
import matplotlib.pyplot as plt
import seaborn as sns
import tensorflow as tf
import requests
from collections import deque

# Initialize MediaPipe Face Detection
mp_face_detection = mp.solutions.face_detection
face_detection = mp_face_detection.FaceDetection(min_detection_confidence=0.6)

# Load improved emotion detection model
model_path = "better_emotion_model.h5"

if not os.path.exists(model_path):
    print("Downloading better emotion model...")
    model_url = "https://github.com/justinshenk/fer/raw/master/models/fer2013_mini_XCEPTION.110-0.65.hdf5"
    response = requests.get(model_url, stream=True)
    with open(model_path, "wb") as f:
        for chunk in response.iter_content(chunk_size=8192):
            f.write(chunk)
    print("Model downloaded!")

try:
    model = load_model(model_path)
    print("Loaded improved emotion detection model!")
except Exception as e:
    print(f"Error loading model: {e}")
    
    # Fallback model
    model = tf.keras.Sequential([
        tf.keras.layers.Conv2D(64, (3, 3), activation='relu', input_shape=(48, 48, 1)),
        tf.keras.layers.MaxPooling2D((2, 2)),
        tf.keras.layers.Conv2D(128, (3, 3), activation='relu'),
        tf.keras.layers.MaxPooling2D((2, 2)),
        tf.keras.layers.Conv2D(256, (3, 3), activation='relu'),
        tf.keras.layers.MaxPooling2D((2, 2)),
        tf.keras.layers.Flatten(),
        tf.keras.layers.Dense(128, activation='relu'),
        tf.keras.layers.Dropout(0.5),
        tf.keras.layers.Dense(7, activation='softmax')
    ])
    
    model.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])
    print("Loaded fallback CNN model.")

# Emotion categories
emotion_labels = ['Angry', 'Disgust', 'Fear', 'Happy', 'Neutral', 'Sad', 'Surprise']

# Initialize webcam
cap = cv2.VideoCapture(0)
prediction_history = deque(maxlen=5)  # Reduce smoothing for faster updates

def preprocess_face(face_roi):
    """Preprocess the face image before feeding it to the model."""
    gray = cv2.cvtColor(face_roi, cv2.COLOR_BGR2GRAY)
    gray = cv2.resize(gray, (48, 48))
    gray = gray.astype("float32") / 255.0
    gray = np.expand_dims(gray, axis=0)  # Batch dimension
    gray = np.expand_dims(gray, axis=-1)  # Add channel dimension
    return gray

print("Starting improved emotion detection... Press 'q' to quit.")

while True:
    ret, frame = cap.read()
    if not ret:
        break
    
    frame = cv2.flip(frame, 1)  # Flip for a mirror effect
    h, w, _ = frame.shape
    
    # Convert to RGB for MediaPipe
    rgb_frame = cv2.cvtColor(frame, cv2.COLOR_BGR2RGB)
    
    # Detect faces using MediaPipe
    results = face_detection.process(rgb_frame)
    
    if results.detections:
        for detection in results.detections:
            bbox = detection.location_data.relative_bounding_box
            x, y, w_box, h_box = int(bbox.xmin * w), int(bbox.ymin * h), int(bbox.width * w), int(bbox.height * h)
            
            # Expand bounding box to avoid tight cropping
            padding = 20  
            x, y = max(0, x - padding), max(0, y - padding)
            w_box, h_box = min(w, w_box + 2 * padding), min(h, h_box + 2 * padding)
            
            face_roi = frame[y:y+h_box, x:x+w_box]
            if face_roi.size == 0:
                continue

            # Preprocess face for emotion model
            face = preprocess_face(face_roi)
            
            # Get emotion prediction
            prediction = model.predict(face, verbose=0)[0]
            print(f"Raw model output: {prediction}")  # Debugging output

            # Add to history for smoothing
            prediction_history.append(prediction)
            
            # Apply weighted smoothing
            if len(prediction_history) > 1:
                weights = np.linspace(0.8, 1.0, len(prediction_history))  # Favor recent predictions
                weights = weights / np.sum(weights)
                smoothed_prediction = np.zeros_like(prediction)
                for i, p in enumerate(prediction_history):
                    smoothed_prediction += weights[i] * p
            else:
                smoothed_prediction = prediction

            # Get the top emotion
            emotion = emotion_labels[np.argmax(smoothed_prediction)]
            confidence = smoothed_prediction[np.argmax(smoothed_prediction)] * 100
            
            # Draw the face bounding box
            cv2.rectangle(frame, (x, y), (x + w_box, y + h_box), (0, 255, 0), 2)
            
            # Display emotion label
            cv2.putText(frame, f"{emotion}: {confidence:.1f}%", (x, y - 10), 
                        cv2.FONT_HERSHEY_SIMPLEX, 0.7, (0, 255, 0), 2)

    else:
        cv2.putText(frame, "No face detected", (30, 30), cv2.FONT_HERSHEY_SIMPLEX, 1, (0, 0, 255), 2)
    
    # Display the frame
    cv2.imshow('Improved Emotion Detection', frame)
    
    # Quit on 'q' key
    if cv2.waitKey(1) & 0xFF == ord('q'):
        break

cap.release()
cv2.destroyAllWindows()
# Out:
# I0000 00:00:1743556997.676671       1 gl_context.cc:344] GL version: 2.1 (2.1 Metal - 89.3), renderer: Apple M2 Pro
# /Users/aiden/Library/Python/3.9/lib/python/site-packages/keras/src/layers/convolutional/base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Error loading model: Unable to synchronously open file (file signature not found)
# Loaded fallback CNN model.
# Starting improved emotion detection... Press 'q' to quit.
# Raw model output: [0.1423834  0.14168    0.14341727 0.1432303  0.14237101 0.1433844
#  0.14353363]
# Raw model output: [0.14236432 0.14109242 0.14327848 0.14364776 0.14216009 0.1436437
#  0.14381318]
# Raw model output: [0.14160721 0.14064574 0.1435779  0.14428386 0.14205031 0.14374448
#  0.14409044]
# Raw model output: [0.14179675 0.14024083 0.14357816 0.14440817 0.14196369 0.1438176
#  0.14419478]
# Raw model output: [0.14210844 0.14028399 0.14347224 0.14427365 0.14222848 0.14376701
#  0.14386617]
# Raw model output: [0.14207634 0.14019793 0.14360747 0.14425136 0.14209399 0.1439077
#  0.14386521]
# Raw model output: [0.1419443  0.14022855 0.14358439 0.14433768 0.14203756 0.1438714
#  0.1439961 ]
# Raw model output: [0.14199121 0.14026873 0.14371918 0.14425674 0.14212155 0.14396162
#  0.14368103]
# Raw model output: [0.14217813 0.14034384 0.1437802  0.14416817 0.1420298  0.14387104
#  0.14362885]
# Raw model output: [0.14203918 0.14030515 0.14351341 0.14429384 0.14216022 0.14395209
#  0.14373612]
# Raw model output: [0.14224775 0.14006214 0.14367476 0.14436372 0.14217342 0.14386111
#  0.14361708]
# Raw model output: [0.14225225 0.14002551 0.14374907 0.14427821 0.14222652 0.1439917
#  0.1434768 ]
# Raw model output: [0.14219287 0.14016646 0.14365606 0.14435107 0.14213748 0.1438734
#  0.14362259]
# Raw model output: [0.14215305 0.14029638 0.1436799  0.14427167 0.14208856 0.14388476
#  0.14362563]
# Raw model output: [0.14206524 0.1403283  0.14376931 0.14428394 0.14204083 0.14400022
#  0.14351211]
# Raw model output: [0.14209862 0.14030609 0.14357255 0.14436938 0.14214483 0.14391914
#  0.14358945]
# Raw model output: [0.14221817 0.14031678 0.14363733 0.14435428 0.14215878 0.14383478
#  0.14347985]
# Raw model output: [0.14228429 0.1403468  0.14352389 0.14424485 0.14222519 0.14385878
#  0.14351618]
# Raw model output: [0.14234719 0.1405445  0.14338785 0.14407527 0.14232148 0.14379232
#  0.14353141]
# Raw model output: [0.14218467 0.14045735 0.14342766 0.1442696  0.14217374 0.14389566
#  0.14359131]
# Raw model output: [0.14242548 0.1404487  0.14339475 0.14416806 0.14202689 0.14391118
#  0.14362496]
# Raw model output: [0.14234091 0.14048162 0.1432606  0.14424422 0.14219931 0.14382616
#  0.14364713]
# Raw model output: [0.14236481 0.14062962 0.1431385  0.14421716 0.14222302 0.14380181
#  0.14362507]
# Raw model output: [0.14236075 0.14051153 0.14317748 0.14419867 0.14221042 0.14388561
#  0.14365554]
# Raw model output: [0.14239165 0.1405049  0.1433631  0.14405362 0.14215845 0.14390647
#  0.14362182]
# Raw model output: [0.14247885 0.14055343 0.14336826 0.14387208 0.1424199  0.14374752
#  0.1435599 ]
# Raw model output: [0.14257818 0.14040445 0.14329413 0.14385927 0.14232428 0.14383507
#  0.14370461]
# Raw model output: [0.14238422 0.14055182 0.14292495 0.14410102 0.14240734 0.14384948
#  0.14378121]
# Raw model output: [0.14255922 0.14064398 0.14302379 0.14377807 0.1422675  0.14373451
#  0.1439929 ]
# Raw model output: [0.14250313 0.1406651  0.14327274 0.14375146 0.14234173 0.14366128
#  0.14380452]
# Raw model output: [0.14242062 0.14054666 0.14334495 0.14387241 0.1422241  0.14387333
#  0.14371797]
# Raw model output: [0.14247784 0.14030375 0.14333786 0.14411071 0.14220063 0.14395909
#  0.14361009]
# Raw model output: [0.14217131 0.14045474 0.14343841 0.14414187 0.1421071  0.14404231
#  0.14364424]
# Raw model output: [0.142305   0.1403186  0.14348182 0.14424114 0.14216006 0.14389595
#  0.14359735]
# Raw model output: [0.14214103 0.14039417 0.14362305 0.14423908 0.14206813 0.14399981
#  0.14353472]
# Raw model output: [0.14230667 0.14027971 0.14354587 0.14425126 0.14217737 0.14392804
#  0.14351112]
# Raw model output: [0.14231035 0.14026788 0.14352423 0.14423989 0.14218129 0.14393446
#  0.14354187]
# Raw model output: [0.14218955 0.14030156 0.1437317  0.1441511  0.1421559  0.14400661
#  0.14346361]
# Raw model output: [0.14228876 0.14015755 0.14372449 0.1441708  0.14209403 0.14400886
#  0.14355552]
# Raw model output: [0.14226821 0.14022353 0.14368854 0.14420724 0.14215675 0.14394404
#  0.14351171]
# Raw model output: [0.14238192 0.14020672 0.14362642 0.14410174 0.14213346 0.14392796
#  0.14362186]
# Raw model output: [0.14237843 0.14021051 0.14351703 0.14432697 0.14203556 0.14399295
#  0.14353852]
# Raw model output: [0.14236239 0.14004567 0.14348538 0.14414465 0.14212608 0.14412282
#  0.1437129 ]
# Raw model output: [0.1424665  0.14025721 0.14358526 0.14404298 0.14208223 0.1439847
#  0.14358102]
# Raw model output: [0.14240977 0.14025122 0.14360867 0.14418602 0.14203772 0.14397909
#  0.14352757]
# Raw model output: [0.14219868 0.14015247 0.14383516 0.1441963  0.14208722 0.14415386
#  0.14337632]
# Raw model output: [0.14229879 0.14015765 0.14356555 0.14424266 0.14210679 0.1440293
#  0.14359926]
# Raw model output: [0.1422562  0.14012393 0.14380038 0.14416432 0.14204963 0.14419258
#  0.14341298]
# Raw model output: [0.14237587 0.14015968 0.14377104 0.14411905 0.14206171 0.14413895
#  0.14337374]
# Raw model output: [0.14237294 0.1401522  0.14356731 0.14422423 0.14210945 0.14397424
#  0.14359961]
# Raw model output: [0.14236364 0.14023991 0.14360914 0.14414583 0.14214656 0.14394355
#  0.14355141]
# Raw model output: [0.1423418  0.14022085 0.14359562 0.14414425 0.1422053  0.1439006
#  0.14359158]
# Raw model output: [0.14245781 0.14022526 0.14354074 0.14405483 0.14210393 0.14401855
#  0.14359888]
# Raw model output: [0.14247252 0.14027506 0.14351846 0.14403039 0.14203766 0.14409891
#  0.14356703]
# Raw model output: [0.14250283 0.14024034 0.14359847 0.14394489 0.1420312  0.14406815
#  0.14361413]
# Raw model output: [0.14231311 0.14024237 0.14358948 0.14412756 0.14212456 0.14396326
#  0.14363964]
# Raw model output: [0.14244366 0.14019498 0.14349991 0.14408055 0.14212498 0.14402786
#  0.14362799]
# Raw model output: [0.14242525 0.14026003 0.14347216 0.144035   0.14214857 0.14404269
#  0.1436164 ]
# Raw model output: [0.14254043 0.14024587 0.143475   0.14400128 0.14201823 0.1440735
#  0.14364566]
# Raw model output: [0.14257208 0.14010209 0.14356805 0.14402333 0.14212954 0.1439627
#  0.14364219]
# Raw model output: [0.14249992 0.1402118  0.14350311 0.14394721 0.1420997  0.14403613
#  0.14370206]
# Raw model output: [0.14238858 0.14034732 0.14338179 0.14414601 0.142134   0.14396372
#  0.14363861]
# Raw model output: [0.1424339  0.1403099  0.1433947  0.14409488 0.14215896 0.14404319
#  0.1435644 ]
# Raw model output: [0.14249238 0.14028731 0.14343105 0.14411438 0.14194742 0.14413117
#  0.14359635]
# Raw model output: [0.14232247 0.14017084 0.14353585 0.1441095  0.1420636  0.14406508
#  0.1437327 ]
# Raw model output: [0.14237754 0.14026678 0.14346503 0.14422125 0.14218256 0.14390112
#  0.14358577]
# Raw model output: [0.14250122 0.1402924  0.14344466 0.14404115 0.14200722 0.1440182
#  0.14369513]
# Raw model output: [0.14247419 0.14033508 0.14354359 0.14403975 0.14215821 0.1439039
#  0.14354524]
# Raw model output: [0.1424319  0.14023916 0.14351554 0.14410466 0.14216334 0.1439366
#  0.1436088 ]
# Raw model output: [0.14236808 0.14029837 0.14336453 0.14412037 0.14215294 0.14402293
#  0.14367273]
# Raw model output: [0.14241552 0.14010815 0.14343847 0.14414392 0.14229468 0.14397906
#  0.14362021]
# Raw model output: [0.14245376 0.14027402 0.14344254 0.14415346 0.14225702 0.14386605
#  0.14355311]
# Raw model output: [0.14239435 0.14032385 0.14340395 0.14415726 0.14226925 0.14386632
#  0.14358495]
# Raw model output: [0.14236872 0.14041401 0.14343144 0.1441645  0.14236532 0.14378743
#  0.14346856]
# Raw model output: [0.14234096 0.14033127 0.1434741  0.14411432 0.14232498 0.14379151
#  0.14362295]
# Raw model output: [0.14218995 0.14040862 0.1433539  0.1441493  0.14236604 0.14389071
#  0.14364158]
# Raw model output: [0.1423859  0.14046364 0.14336987 0.14409682 0.14240506 0.14378856
#  0.14349015]
# Raw model output: [0.1422889  0.14059292 0.14336114 0.14402583 0.14242445 0.14371249
#  0.14359426]
# Raw model output: [0.1424201  0.14057656 0.1432639  0.14404131 0.1423673  0.14375907
#  0.14357172]
# Raw model output: [0.14223889 0.14062981 0.14338222 0.14401418 0.1423941  0.14379762
#  0.14354317]
# Raw model output: [0.14230658 0.14051756 0.14348    0.14406523 0.1424633  0.14372702
#  0.14344034]
# Raw model output: [0.14220814 0.1405977  0.14335072 0.14407948 0.14243172 0.1437417
#  0.14359057]
# Raw model output: [0.14219068 0.14044026 0.14351928 0.14412464 0.14253068 0.14376874
#  0.14342567]
# Raw model output: [0.14225146 0.14045455 0.14342354 0.1442831  0.14248124 0.14373249
#  0.1433736 ]
# Raw model output: [0.14238979 0.14034304 0.14344361 0.14419986 0.1423986  0.14377525
#  0.14344989]
# Raw model output: [0.14231454 0.14035085 0.14339453 0.14412686 0.14238393 0.1439031
#  0.14352621]
# Raw model output: [0.14223501 0.14029434 0.1433415  0.14421293 0.1423478  0.14404334
#  0.14352505]
# Raw model output: [0.14235657 0.1402284  0.14315253 0.14422722 0.14232141 0.14407443
#  0.14363943]
# Raw model output: [0.1422993  0.140345   0.14319597 0.14421917 0.14243521 0.14395002
#  0.14355536]
# Raw model output: [0.14228752 0.140551   0.14330445 0.14408913 0.14230482 0.14385055
#  0.1436124 ]
# Raw model output: [0.14237395 0.1407148  0.14340267 0.14393155 0.14216912 0.14381355
#  0.14359443]
# Raw model output: [0.14262028 0.14089274 0.14338392 0.14379899 0.14219727 0.14371662
#  0.14339016]
# Raw model output: [0.14259389 0.1408123  0.14315896 0.14387496 0.1422201  0.14388655
#  0.14345327]
# Raw model output: [0.14259014 0.14078672 0.14327033 0.14371455 0.14231107 0.14382927
#  0.1434979 ]
# Raw model output: [0.14254187 0.14086916 0.14313103 0.14380857 0.14229725 0.14375247
#  0.1435996 ]
# Raw model output: [0.14237738 0.14107731 0.14321631 0.14372127 0.1422384  0.14370134
#  0.14366795]
# Raw model output: [0.14198983 0.14117065 0.14333196 0.1438193  0.14218454 0.14356829
#  0.14393543]
# Raw model output: [0.14191756 0.14138235 0.1435204  0.1433647  0.14246432 0.14341605
#  0.14393468]
# Raw model output: [0.14149529 0.14120841 0.14349067 0.1439628  0.14237146 0.14341722
#  0.1440541 ]
# Raw model output: [0.14236929 0.13888237 0.14378121 0.14487886 0.14168552 0.14442343
#  0.14397934]
# Raw model output: [0.14158869 0.13830459 0.14416443 0.14511651 0.14195721 0.14463863
#  0.14422998]
# Raw model output: [0.14154214 0.13831718 0.14378281 0.1452939  0.14231002 0.14485964
#  0.14389426]
# Raw model output: [0.14142202 0.13837959 0.14434181 0.14508818 0.14230117 0.14451504
#  0.14395219]
# Raw model output: [0.14136676 0.13861795 0.14387977 0.14497061 0.14232853 0.14459701
#  0.14423934]
# Raw model output: [0.1414567  0.13880722 0.14381152 0.14482057 0.14226602 0.14461526
#  0.14422269]
# Raw model output: [0.14130896 0.13893835 0.14393942 0.14505202 0.1422522  0.14436947
#  0.14413957]
# Raw model output: [0.14146028 0.13845845 0.14402822 0.1452918  0.14225951 0.14447403
#  0.14402765]
# Raw model output: [0.14152302 0.13808131 0.14377794 0.14552306 0.14217314 0.14484376
#  0.1440777 ]
# Raw model output: [0.14142916 0.13792826 0.14377442 0.14532362 0.14240266 0.14465606
#  0.14448585]
# Raw model output: [0.14106819 0.1381821  0.1444652  0.14498578 0.14247239 0.14477879
#  0.14404753]
# Raw model output: [0.14123255 0.13780667 0.14425343 0.14515977 0.14260708 0.14484435
#  0.14409618]
# Raw model output: [0.14097919 0.13836789 0.1441218  0.144914   0.14213961 0.14483988
#  0.14463761]
# Raw model output: [0.1411302  0.13824184 0.14436494 0.14492738 0.14219575 0.1447477
#  0.14439222]
# Raw model output: [0.14105883 0.13789363 0.14440961 0.14495312 0.14257771 0.14496167
#  0.14414543]
# Raw model output: [0.14109634 0.13784525 0.14409433 0.14486948 0.14242247 0.14510767
#  0.14456452]
# Raw model output: [0.1413153  0.13792145 0.14427769 0.14482532 0.14265667 0.1448154
#  0.14418821]
# Raw model output: [0.14112651 0.13797258 0.14426197 0.14486574 0.14240299 0.1450108
#  0.14435937]
# Raw model output: [0.14109197 0.13799447 0.14434189 0.14489694 0.14253174 0.14491281
#  0.14423019]
# Raw model output: [0.14116372 0.13805862 0.14407381 0.14492698 0.14246306 0.14492972
#  0.14438409]
# Raw model output: [0.14092796 0.13788813 0.14414978 0.14498058 0.14252964 0.14497055
#  0.14455335]
# Raw model output: [0.14102559 0.13782907 0.14402696 0.14507377 0.14237055 0.14510539
#  0.14456865]
# Raw model output: [0.14090262 0.13773966 0.14392143 0.14503963 0.14234203 0.14537372
#  0.14468095]
# Raw model output: [0.14092314 0.13778263 0.14392856 0.1450821  0.14234422 0.14529349
#  0.1446458 ]
# Raw model output: [0.14110991 0.13791956 0.14382042 0.14510463 0.14263707 0.14506346
#  0.14434491]
# Raw model output: [0.1409636  0.13776925 0.14400458 0.14498802 0.14231637 0.14531821
#  0.14464001]
# Raw model output: [0.14109424 0.1377641  0.1439871  0.14497973 0.1423938  0.14519855
#  0.14458254]
# Raw model output: [0.14118305 0.13781942 0.14393784 0.1450357  0.1423638  0.14521429
#  0.14444582]
# Raw model output: [0.14073652 0.13786669 0.14416467 0.14475398 0.14243025 0.14517409
#  0.14487381]
# Raw model output: [0.14082167 0.13746813 0.14444731 0.14528881 0.14244048 0.14511603
#  0.14441757]
# Raw model output: [0.14079356 0.13745648 0.14426456 0.14534517 0.14253117 0.14520067
#  0.14440843]
# Raw model output: [0.14102325 0.13771307 0.1440608  0.14511156 0.142584   0.14494856
#  0.14455879]
# Raw model output: [0.14069137 0.13771816 0.14441518 0.14484434 0.14248812 0.14533068
#  0.14451213]
# Raw model output: [0.14091416 0.13753924 0.14481261 0.14493829 0.14254731 0.1451409
#  0.14410739]
# Raw model output: [0.14089012 0.13759576 0.1446535  0.14495459 0.14253311 0.14516133
#  0.14421158]
# Raw model output: [0.14076069 0.1377188  0.14458632 0.14484447 0.1426232  0.14516273
#  0.14430381]
# Raw model output: [0.1407777  0.1376334  0.14478093 0.14501432 0.14245825 0.1451092
#  0.14422618]
# Raw model output: [0.14076161 0.13766247 0.14481953 0.14484337 0.14255083 0.14515607
#  0.14420603]
# Raw model output: [0.14073834 0.13761313 0.14476167 0.14477246 0.14244623 0.1453073
#  0.14436084]
# Raw model output: [0.14114597 0.1377146  0.14416273 0.1446537  0.1422177  0.14535427
#  0.14475104]
# Raw model output: [0.14084856 0.13776474 0.14378338 0.14520346 0.1423048  0.14522104
#  0.14487407]
# Raw model output: [0.14111681 0.13781358 0.14394492 0.14534009 0.14186005 0.14525662
#  0.14466792]
# Raw model output: [0.1414191  0.13778175 0.1436803  0.14550297 0.1417883  0.14497896
#  0.14484857]
# Raw model output: [0.14150329 0.13740957 0.14358203 0.1455212  0.14207917 0.14530128
#  0.14460345]
# Raw model output: [0.1415366  0.13778064 0.14357412 0.14531636 0.14202233 0.14514577
#  0.14462417]
# Raw model output: [0.14134727 0.13795403 0.14387316 0.14517777 0.14189348 0.1448969
#  0.14485748]
# Raw model output: [0.14130747 0.13794427 0.143687   0.14515302 0.14179842 0.14518003
#  0.14492983]
# Raw model output: [0.14161356 0.1375134  0.14338437 0.14538118 0.14192747 0.14544255
#  0.1447375 ]
# Raw model output: [0.14136922 0.13782379 0.14373209 0.14527547 0.14171325 0.14532106
#  0.14476518]
# Raw model output: [0.14144172 0.13783747 0.14326875 0.14534104 0.14179173 0.14523005
#  0.14508921]
# Raw model output: [0.14138511 0.13785438 0.14372441 0.1453735  0.1415117  0.14537103
#  0.1447798 ]
# Raw model output: [0.14140163 0.13767532 0.1437178  0.14526266 0.14188686 0.14522456
#  0.14483124]
# Raw model output: [0.14139615 0.13803814 0.14337413 0.14538835 0.14180657 0.14501616
#  0.14498053]
# Raw model output: [0.14144807 0.13781561 0.14336286 0.14534877 0.14197023 0.14500502
#  0.14504944]
# Raw model output: [0.14150098 0.13765296 0.14372529 0.14532039 0.14198802 0.14506458
#  0.14474773]
# Raw model output: [0.14132775 0.13795714 0.14358363 0.14535394 0.14190575 0.14527997
#  0.1445918 ]
# Raw model output: [0.14152773 0.1379077  0.14359646 0.14526743 0.14174733 0.14506382
#  0.14488958]
# Raw model output: [0.14141531 0.1380456  0.1436275  0.14535393 0.14177482 0.14512831
#  0.1446546 ]
# Raw model output: [0.1417587  0.13809519 0.14369473 0.14514804 0.14189427 0.14490408
#  0.14450498]
# Raw model output: [0.14165092 0.13815847 0.14380458 0.14513293 0.14202859 0.14448592
#  0.14473855]
# Raw model output: [0.14135158 0.13815653 0.14363155 0.14529607 0.14175783 0.14495844
#  0.14484805]
# Raw model output: [0.14146991 0.13822849 0.14378396 0.14520577 0.14167076 0.1448629
#  0.14477827]
# Raw model output: [0.14111285 0.13827379 0.1437081  0.14524372 0.14186676 0.14487667
#  0.14491802]
# Raw model output: [0.14122868 0.13802111 0.14349143 0.1454064  0.14165023 0.14527687
#  0.14492528]
# Raw model output: [0.14155467 0.13880163 0.14368643 0.14509906 0.14224945 0.14469889
#  0.14390993]
# Raw model output: [0.14137101 0.13828966 0.14424929 0.14494215 0.14247157 0.14419092
#  0.14448537]
# Raw model output: [0.14090025 0.13821529 0.14444594 0.14498107 0.14241253 0.14465022
#  0.14439474]
# Raw model output: [0.14114557 0.1381946  0.14458592 0.14481322 0.14241067 0.14489904
#  0.14395091]
# Raw model output: [0.14122583 0.13813965 0.14454119 0.14486891 0.14253461 0.14457981
#  0.14410989]
# Raw model output: [0.14098063 0.13819888 0.144549   0.14489943 0.14239593 0.1448479
#  0.14412825]
# Raw model output: [0.14092092 0.13809049 0.1444501  0.14488247 0.14234033 0.14505729
#  0.14425842]
# Raw model output: [0.1412383  0.13835596 0.1442079  0.14507346 0.14240344 0.14453082
#  0.14419018]
# Raw model output: [0.14135146 0.13824119 0.1445212  0.14489566 0.14238633 0.14448842
#  0.14411575]
# Raw model output: [0.14142749 0.13810834 0.14454018 0.1449226  0.14233442 0.14460324
#  0.14406373]
# Raw model output: [0.14128275 0.13803904 0.14444098 0.1450192  0.14249155 0.1444589
#  0.14426753]
# Raw model output: [0.14147966 0.13800064 0.14440887 0.14507218 0.14256987 0.14432192
#  0.14414692]
# Raw model output: [0.14122494 0.13800623 0.1442583  0.14526412 0.14241144 0.14489171
#  0.14394331]
# Raw model output: [0.14138092 0.13796164 0.14485286 0.1451271  0.1424822  0.14448862
#  0.14370671]
# Raw model output: [0.1413252  0.13801889 0.1445998  0.14535373 0.14264597 0.14449564
#  0.14356078]
# Raw model output: [0.14134498 0.13793898 0.14467022 0.14518914 0.14246371 0.14474396
#  0.14364906]
# Raw model output: [0.14151396 0.13762781 0.14482109 0.14515682 0.14279808 0.14429052
#  0.14379178]
# Raw model output: [0.14129563 0.13790427 0.14495687 0.14475206 0.14278246 0.14449118
#  0.1438175 ]
# Raw model output: [0.14137892 0.13763832 0.14455779 0.1447766  0.14283653 0.14466979
#  0.14414208]
# Raw model output: [0.14149928 0.1376002  0.1444935  0.14483456 0.14274833 0.14472741
#  0.14409666]
# Raw model output: [0.14130145 0.1377424  0.14477737 0.14473437 0.1428816  0.14456092
#  0.14400196]
# Raw model output: [0.14122464 0.1379287  0.1444755  0.14482294 0.14280804 0.14455545
#  0.14418471]
# Raw model output: [0.14113341 0.13799644 0.14463226 0.14479384 0.14291501 0.1444972
#  0.14403184]
# Raw model output: [0.14109197 0.13793568 0.14455739 0.14492704 0.14285816 0.14443482
#  0.14419489]
# Raw model output: [0.14088976 0.13794686 0.14509746 0.14497904 0.14239751 0.14485538
#  0.14383394]
# Raw model output: [0.14113466 0.13802235 0.1449525  0.14475808 0.14260325 0.1447529
#  0.14377627]
# Raw model output: [0.14101748 0.13794681 0.14477754 0.14484273 0.14273407 0.14455517
#  0.14412628]
# Raw model output: [0.14128506 0.13813269 0.14471257 0.14437684 0.14270836 0.14453271
#  0.14425184]
# Raw model output: [0.14131011 0.13804726 0.14432105 0.14477812 0.14268576 0.14479136
#  0.14406633]
# Raw model output: [0.14145356 0.1383393  0.14416167 0.14464986 0.14254014 0.14470929
#  0.1441461 ]
# Raw model output: [0.14137985 0.13822734 0.14411366 0.14466624 0.14256687 0.14474955
#  0.14429645]
# Raw model output: [0.14119776 0.13829704 0.14418058 0.1446488  0.14258167 0.14465874
#  0.14443535]
# Raw model output: [0.1413892  0.13842244 0.14422993 0.14433397 0.14270207 0.14435531
#  0.144567  ]
# Raw model output: [0.1410709  0.13824211 0.1442729  0.14446814 0.14260371 0.14477399
#  0.14456822]
# Raw model output: [0.14080717 0.13823482 0.14482857 0.14456972 0.1426949  0.14462306
#  0.14424178]
# Raw model output: [0.14099732 0.13822526 0.14455596 0.1446993  0.14248112 0.14478645
#  0.14425458]
# Raw model output: [0.14076729 0.13813916 0.14468281 0.1445933  0.14258735 0.14483532
#  0.14439479]
# Raw model output: [0.14067571 0.1383697  0.1446844  0.14465867 0.14240557 0.1447758
#  0.14443019]
# Raw model output: [0.1409436  0.13832757 0.14440317 0.14468805 0.1422949  0.14489077
#  0.1444519 ]
# Raw model output: [0.14068416 0.1381174  0.1443024  0.14470278 0.14243662 0.14509007
#  0.14466654]
# Raw model output: [0.14090648 0.1379626  0.14440289 0.14487891 0.14260218 0.14475979
#  0.14448711]
# Raw model output: [0.14061278 0.1383208  0.1442761  0.14475611 0.1424966  0.1450797
#  0.14445788]
# Raw model output: [0.14064658 0.13818751 0.14439254 0.14470659 0.14242527 0.14512148
#  0.14452001]
# Raw model output: [0.14097378 0.13793142 0.14431179 0.14477739 0.14233673 0.14514652
#  0.14452237]
# Raw model output: [0.14106327 0.13789406 0.14449666 0.14496978 0.14221936 0.14506534
#  0.14429149]
# Raw model output: [0.14102072 0.13795228 0.1442948  0.14491501 0.14226304 0.14512655
#  0.14442761]
# Raw model output: [0.14089778 0.13805582 0.1442324  0.14485662 0.14224565 0.14510424
#  0.14460747]
# Raw model output: [0.14109406 0.13792361 0.1442602  0.14478    0.14247794 0.14504336
#  0.1444208 ]
# Raw model output: [0.14081262 0.13788828 0.14441352 0.14484388 0.14232945 0.14501782
#  0.14469437]
# Raw model output: [0.14089759 0.1379239  0.14457068 0.1449072  0.14217784 0.14495307
#  0.14456974]
# Raw model output: [0.14102402 0.13792506 0.14445266 0.14499797 0.14205518 0.14499077
#  0.14455435]
# Raw model output: [0.14101042 0.13812509 0.1447518  0.14464466 0.14244227 0.14467466
#  0.14435105]
# Raw model output: [0.14115585 0.13797662 0.14436169 0.1447081  0.14221445 0.14510532
#  0.14447804]
# Raw model output: [0.14111228 0.13812183 0.14450733 0.14487033 0.14209913 0.14475513
#  0.14453398]
# Raw model output: [0.14085238 0.1379779  0.14434546 0.14519688 0.14196056 0.14496958
#  0.14469725]
# Raw model output: [0.14088288 0.13802844 0.14395744 0.14527003 0.1419379  0.14507705
#  0.14484628]
# Raw model output: [0.14096332 0.13781007 0.14406878 0.14509626 0.14202179 0.14522159
#  0.14481822]
# Raw model output: [0.14097331 0.13769369 0.1439817  0.14509673 0.14225854 0.14526612
#  0.14472994]
# Raw model output: [0.1406923  0.13780724 0.14459318 0.14482316 0.14259306 0.14493783
#  0.14455326]
# Raw model output: [0.1410083  0.13773377 0.14471683 0.14476112 0.14240927 0.14498845
#  0.14438222]
# Raw model output: [0.14085756 0.13778158 0.14465801 0.14489289 0.14252687 0.1447183
#  0.14456484]
# Raw model output: [0.1412405  0.13776526 0.14401262 0.14497387 0.14257222 0.14477956
#  0.14465602]
# Raw model output: [0.14127314 0.13769834 0.1440386  0.14495476 0.14258505 0.14491107
#  0.14453904]
# Raw model output: [0.14122711 0.13779943 0.14399362 0.14490913 0.14262453 0.14486948
#  0.14457671]
# Raw model output: [0.14112224 0.13782115 0.14424345 0.14489271 0.1424403  0.14500298
#  0.14447711]
# Raw model output: [0.14122504 0.13772589 0.14398545 0.14506929 0.14261232 0.1447917
#  0.14459026]
# Raw model output: [0.14119223 0.13767065 0.14413767 0.14490533 0.1425534  0.14505117
#  0.14448959]
# Raw model output: [0.14117044 0.13775149 0.14395617 0.14508805 0.14254463 0.14485091
#  0.14463827]
# Raw model output: [0.14083752 0.1376463  0.1446503  0.14492032 0.14251934 0.1449043
#  0.14452194]
# Raw model output: [0.14094664 0.13757978 0.14465138 0.1448799  0.14246044 0.14507443
#  0.14440742]
# Raw model output: [0.14106992 0.13766095 0.1444413  0.14481701 0.14214917 0.14526655
#  0.14459506]
# Raw model output: [0.14102    0.13769475 0.14418055 0.14514627 0.14229041 0.14508656
#  0.14458148]
# Raw model output: [0.1412171  0.13826309 0.14435734 0.14488451 0.1421166  0.14463396
#  0.14452739]
# Raw model output: [0.14146207 0.13838999 0.14412743 0.14465271 0.14270413 0.14467095
#  0.14399268]
# Raw model output: [0.14147319 0.13826105 0.14416312 0.14507538 0.14242946 0.14441332
#  0.14418447]
# Raw model output: [0.14162529 0.13850592 0.1436831  0.14502706 0.14210206 0.14479515
#  0.14426142]
# Raw model output: [0.14175004 0.13819535 0.14359084 0.1451735  0.14203791 0.14504376
#  0.14420865]
# Raw model output: [0.1420483  0.13816738 0.14331754 0.14519489 0.14199735 0.1451194
#  0.14415516]
# Raw model output: [0.14197713 0.13849413 0.14397044 0.14470944 0.14181232 0.14497901
#  0.14405751]
# Raw model output: [0.14181815 0.13866535 0.1438793  0.14488722 0.14178135 0.14502896
#  0.1439397 ]
# Raw model output: [0.14212704 0.13871548 0.14330979 0.14505649 0.14202587 0.14482392
#  0.1439414 ]
# Raw model output: [0.14200348 0.13850962 0.14349337 0.14500588 0.14201818 0.14500646
#  0.143963  ]
# Raw model output: [0.14173964 0.13901901 0.143733   0.14511813 0.14161134 0.14484797
#  0.14393087]
# Raw model output: [0.14187372 0.13882917 0.1438536  0.14493047 0.14200298 0.14469752
#  0.1438125 ]
# Raw model output: [0.14198391 0.13866602 0.14360373 0.14507434 0.14201649 0.1448403
#  0.14381522]
# Raw model output: [0.14183599 0.13893759 0.14359285 0.14518265 0.14162882 0.14479257
#  0.14402953]
# Raw model output: [0.1420949  0.13858931 0.14333203 0.14518404 0.14193383 0.14484349
#  0.14402232]
# Raw model output: [0.14203422 0.13846189 0.14365458 0.14506066 0.14186606 0.14498681
#  0.14393586]
# Raw model output: [0.14213614 0.13843751 0.14327845 0.14508022 0.14196883 0.1450342
#  0.1440646 ]
# Raw model output: [0.14198251 0.13859572 0.14360034 0.14493656 0.14184706 0.14505942
#  0.14397834]
# Raw model output: [0.14191392 0.13852972 0.14368942 0.14504206 0.14174901 0.14509761
#  0.14397827]
# Raw model output: [0.14202963 0.13851793 0.14369182 0.14505537 0.14175534 0.14494158
#  0.14400831]
# Raw model output: [0.14192311 0.13846706 0.14362125 0.14514722 0.1418907  0.14494912
#  0.14400145]
# Raw model output: [0.14195867 0.13845605 0.14359888 0.14506075 0.14182252 0.14509639
#  0.14400677]
# Raw model output: [0.14191984 0.13855429 0.14342006 0.14512305 0.14180394 0.14505039
#  0.14412844]
# Raw model output: [0.14183693 0.13856643 0.14378507 0.14509381 0.14189777 0.14491506
#  0.14390491]
# Raw model output: [0.141948   0.1384369  0.14357053 0.14506932 0.14192647 0.14506829
#  0.1439805 ]
# Raw model output: [0.14168768 0.13840772 0.14407447 0.14502947 0.14212589 0.14479408
#  0.14388074]
# Raw model output: [0.1418458  0.13820459 0.14403929 0.14488636 0.14242937 0.1447213
#  0.14387332]
# Raw model output: [0.14145319 0.1381513  0.14408696 0.14532071 0.14230949 0.14425592
#  0.14442246]
# Raw model output: [0.14117964 0.13814332 0.14393136 0.14547999 0.14202705 0.14450537
#  0.14473325]
# Raw model output: [0.1413219  0.13731368 0.14376667 0.14576086 0.14229032 0.14468306
#  0.14486353]
# Raw model output: [0.14109953 0.1373385  0.14345677 0.1459638  0.14181177 0.14494857
#  0.14538103]
# Raw model output: [0.14103957 0.13787416 0.14363801 0.1454836  0.14198603 0.14474094
#  0.14523774]
# Raw model output: [0.14104632 0.13761975 0.14366616 0.14514469 0.14235821 0.14494911
#  0.14521573]
# Raw model output: [0.14101408 0.13750271 0.14375685 0.14552845 0.1417762  0.14509922
#  0.14532241]
# Raw model output: [0.14092933 0.13758397 0.14366074 0.1456532  0.14216192 0.14449954
#  0.14551137]
# Raw model output: [0.14132737 0.13759154 0.14364716 0.14531499 0.142143   0.14499143
#  0.14498444]
# Raw model output: [0.1412238  0.13751458 0.14344    0.14544742 0.14251804 0.1448942
#  0.14496194]
# Raw model output: [0.1408618  0.13731992 0.14393507 0.14576097 0.14229801 0.1444914
#  0.14533287]
# Raw model output: [0.14102277 0.13738897 0.1439431  0.14573449 0.14241587 0.14439295
#  0.1451018 ]
# Raw model output: [0.14128174 0.13728255 0.14345185 0.14583604 0.14210556 0.14500149
#  0.14504077]
# Raw model output: [0.14110921 0.13716006 0.1436043  0.14607285 0.14218277 0.14487459
#  0.14499623]
# Raw model output: [0.14117514 0.1372799  0.14367928 0.14584762 0.1423337  0.14492252
#  0.1447619 ]
# Raw model output: [0.14100069 0.13749747 0.14356604 0.1456734  0.14237192 0.14483815
#  0.14505228]
# Raw model output: [0.14118494 0.13719353 0.14354146 0.14608055 0.14241752 0.14468285
#  0.14489917]
# Raw model output: [0.14111099 0.13745965 0.14364113 0.14603694 0.14222382 0.14446722
#  0.14506027]
# Raw model output: [0.14110649 0.13744451 0.14376111 0.14578182 0.14223874 0.1450866
#  0.1445808 ]
# Raw model output: [0.14136988 0.13720015 0.14395203 0.14592773 0.14204599 0.14489265
#  0.14461157]
# Raw model output: [0.14104843 0.13744022 0.14377664 0.14584604 0.14225107 0.14502324
#  0.14461432]
# Raw model output: [0.14098205 0.1373613  0.14368582 0.14617936 0.141901   0.14488918
#  0.14500128]
# Raw model output: [0.1411751  0.13747469 0.14351927 0.14592203 0.14229189 0.14477849
#  0.1448385 ]
# Raw model output: [0.14119445 0.13677333 0.14338233 0.14622432 0.1424255  0.14509398
#  0.14490609]
# Raw model output: [0.14086595 0.1379184  0.14389428 0.14557418 0.14278644 0.14473155
#  0.14422922]
# Raw model output: [0.14131454 0.13767557 0.14309968 0.14509113 0.1429197  0.14463875
#  0.1452607 ]
# Raw model output: [0.14124563 0.13790986 0.14397171 0.14563313 0.142676   0.14447476
#  0.14408892]
# Raw model output: [0.14110835 0.1380025  0.14372145 0.14587043 0.14230908 0.145016
#  0.14397222]
# Raw model output: [0.140676   0.13734674 0.14414527 0.14641178 0.14248706 0.14523505
#  0.14369808]
# Raw model output: [0.14018846 0.13754812 0.14441866 0.14645638 0.14251205 0.14534596
#  0.1435303 ]
# Raw model output: [0.14078552 0.13735792 0.14434668 0.1462223  0.1423526  0.145035
#  0.14390007]
# Raw model output: [0.14094228 0.13732916 0.14404899 0.14647007 0.14227405 0.14494765
#  0.14398783]
# Raw model output: [0.1408177  0.13735785 0.14410023 0.14637685 0.1422902  0.1450816
#  0.14397559]
# Raw model output: [0.14087121 0.1375075  0.14397247 0.14642704 0.14225194 0.14500108
#  0.14396878]
# Raw model output: [0.14087984 0.13772541 0.14400792 0.14627276 0.14224659 0.14517768
#  0.14368986]
# Raw model output: [0.14064106 0.13766639 0.14428735 0.14636531 0.14233822 0.14525999
#  0.14344178]
# Raw model output: [0.14081018 0.13726902 0.14451928 0.14628956 0.14219373 0.1448915
#  0.14402665]
# Raw model output: [0.14106554 0.13694622 0.14380011 0.14660203 0.14207037 0.14521915
#  0.14429657]
# Raw model output: [0.14128003 0.13683985 0.14383796 0.14647211 0.14205207 0.14518778
#  0.14433022]
# Raw model output: [0.14113973 0.13719025 0.14397784 0.14631647 0.14211942 0.14501967
#  0.14423655]
# Raw model output: [0.14101525 0.13730896 0.14392804 0.14617123 0.14198907 0.14515351
#  0.14443392]
# Raw model output: [0.14105551 0.13726467 0.14409295 0.14627703 0.14236231 0.1450024
#  0.1439451 ]
# Raw model output: [0.141217   0.13762198 0.14406003 0.14580959 0.1426915  0.14462264
#  0.14397724]
# Raw model output: [0.14177315 0.13758625 0.14313552 0.14577183 0.14272676 0.1443601
#  0.14464638]
# Raw model output: [0.1413167  0.13782302 0.14315057 0.14607261 0.1426137  0.14430858
#  0.14471474]
# Raw model output: [0.14131486 0.138206   0.14395757 0.14522818 0.14270394 0.14435674
#  0.14423269]
# Raw model output: [0.14134078 0.13787939 0.14400625 0.14550537 0.14261678 0.14468126
#  0.14397019]
# Raw model output: [0.14111489 0.1381713  0.14443381 0.1449211  0.14250916 0.14486557
#  0.14398411]
# Raw model output: [0.14113265 0.1382811  0.14441466 0.14492896 0.14252722 0.14482088
#  0.14389445]
# Raw model output: [0.14131927 0.13847958 0.14439085 0.1447002  0.14253995 0.14481042
#  0.14375971]
# Raw model output: [0.14129281 0.13863589 0.14429589 0.14496638 0.14263922 0.14470261
#  0.14346714]
# Raw model output: [0.14131162 0.1385143  0.14447261 0.1448584  0.14252499 0.14475967
#  0.14355837]
# Raw model output: [0.14161594 0.13852544 0.1442648  0.14465924 0.14240764 0.14477561
#  0.14375134]
# Raw model output: [0.14150685 0.13866301 0.14430258 0.14461717 0.14239103 0.14481157
#  0.14370777]
# Raw model output: [0.1416349  0.13856973 0.1442577  0.14478074 0.14250688 0.14469203
#  0.14355801]
# Raw model output: [0.14169016 0.13840799 0.14427006 0.14479455 0.14238703 0.144644
#  0.14380616]
# Raw model output: [0.14155103 0.13858037 0.14429288 0.14483912 0.14248212 0.1446035
#  0.14365101]
# Raw model output: [0.14176935 0.1387488  0.14405191 0.14478478 0.14240867 0.1446186
#  0.14361791]
# Raw model output: [0.14178559 0.13863197 0.14385991 0.14501388 0.1425293  0.14447346
#  0.14370587]
# Raw model output: [0.14185354 0.13857664 0.14387399 0.14508793 0.14254165 0.14440109
#  0.14366509]
# Raw model output: [0.1419063  0.13866132 0.14395405 0.14502245 0.1423919  0.14441867
#  0.14364535]
# Raw model output: [0.14171177 0.13853362 0.14398494 0.14506322 0.1424222  0.14457312
#  0.14371113]
# Raw model output: [0.1420302  0.13838078 0.14370732 0.14501144 0.14245068 0.14465168
#  0.14376795]
# Raw model output: [0.14179651 0.13837855 0.14370467 0.14507575 0.14262468 0.14480232
#  0.14361751]
# Raw model output: [0.14176698 0.13834803 0.14363004 0.14506105 0.14271353 0.14481471
#  0.14366567]
# Raw model output: [0.14172985 0.13832346 0.14388618 0.14508982 0.14243887 0.1448645
#  0.14366733]
# Raw model output: [0.14194527 0.13824466 0.14379857 0.14506118 0.14235693 0.14486973
#  0.14372374]
# Raw model output: [0.1419706  0.13830042 0.14376947 0.14507931 0.14238107 0.1448593
#  0.14363985]
# Raw model output: [0.14195691 0.13825582 0.14372818 0.14507148 0.14234535 0.14496364
#  0.14367859]
# Raw model output: [0.14126363 0.13873802 0.14420499 0.1448216  0.1424622  0.14487344
#  0.14363614]
# Raw model output: [0.14160421 0.1384116  0.14412701 0.14474666 0.14230096 0.1451059
#  0.14370368]
# Raw model output: [0.14175463 0.13862185 0.14405331 0.14492984 0.14249842 0.14469047
#  0.14345144]
# Raw model output: [0.14176871 0.13854928 0.14406803 0.14493462 0.14240986 0.14483562
#  0.14343388]
# Raw model output: [0.14186995 0.13833529 0.14394958 0.14499329 0.14241028 0.14492144
#  0.14352012]
# Raw model output: [0.1419353  0.13806601 0.14387633 0.14517455 0.1424825  0.14492586
#  0.14353941]
# Raw model output: [0.14194062 0.1381321  0.14391011 0.14515342 0.14252265 0.14479932
#  0.14354171]
# Raw model output: [0.14198966 0.13828802 0.14395799 0.14509216 0.14247671 0.144681
#  0.14351448]
# Raw model output: [0.14204338 0.13821474 0.14398226 0.14506716 0.14239447 0.14471789
#  0.14358014]
# Raw model output: [0.14163972 0.13853045 0.14384435 0.14511329 0.14247338 0.1447736
#  0.14362517]
# Raw model output: [0.14190723 0.1386407  0.14401521 0.14497806 0.1424076  0.14441738
#  0.14363384]
# Raw model output: [0.14143328 0.13860221 0.14439386 0.14481468 0.14250505 0.14454919
#  0.14370179]
# Raw model output: [0.14152183 0.13859585 0.14459482 0.14459512 0.1423039  0.1445455
#  0.1438429 ]
# Raw model output: [0.14220895 0.13738391 0.14427477 0.1455607  0.14170854 0.14462014
#  0.14424299]
# Raw model output: [0.14126824 0.1383263  0.14468454 0.14524847 0.1423102  0.14453833
#  0.14362393]
# Raw model output: [0.14135681 0.13741149 0.14407603 0.14558056 0.14230366 0.14463122
#  0.14464019]
# Raw model output: [0.14181715 0.13785563 0.14409465 0.14544852 0.14237759 0.14454699
#  0.14385949]
# Raw model output: [0.14122017 0.1380069  0.14419952 0.14565837 0.14219923 0.14466764
#  0.14404808]
# Raw model output: [0.14119938 0.13809133 0.14383408 0.14569438 0.14200519 0.14475523
#  0.14442036]
# Raw model output: [0.14164527 0.13788633 0.14437272 0.14536954 0.1425993  0.14418298
#  0.14394382]
# Raw model output: [0.14145485 0.13776906 0.14414045 0.1457345  0.14216731 0.14467584
#  0.14405799]
# Raw model output: [0.14152223 0.13777092 0.14401226 0.14554065 0.14237775 0.1446666
#  0.14410962]
# Raw model output: [0.14156368 0.13799283 0.14424612 0.1455084  0.14217304 0.1444736
#  0.14404228]
# Raw model output: [0.1415465  0.13803107 0.14433782 0.14545363 0.14236182 0.14428005
#  0.14398906]
# Raw model output: [0.1417524  0.1378716  0.14411193 0.14533707 0.14245346 0.14437605
#  0.14409754]
# Raw model output: [0.14160705 0.13814777 0.1443065  0.14519061 0.14230666 0.14433564
#  0.14410582]
# Raw model output: [0.14141966 0.13826594 0.14368878 0.14533983 0.14232294 0.14460894
#  0.14435387]
# Raw model output: [0.14173493 0.13813521 0.14417027 0.145062   0.14246346 0.14433828
#  0.14409582]
# Raw model output: [0.14179993 0.13794547 0.14403696 0.14492571 0.14274442 0.14450645
#  0.14404105]
# Raw model output: [0.14173226 0.137941   0.14408618 0.14505564 0.14271668 0.1444276
#  0.14404061]
# Raw model output: [0.14178684 0.1378494  0.14414546 0.14506458 0.14277421 0.1443686
#  0.14401092]
# Raw model output: [0.14193359 0.13767904 0.1438491  0.14481881 0.14274418 0.14471333
#  0.14426191]
# Raw model output: [0.14175849 0.13805583 0.14400768 0.1451081  0.14266285 0.14421879
#  0.1441882 ]
# Raw model output: [0.14160925 0.13812293 0.14398763 0.14513864 0.1423093  0.14439233
#  0.14443992]
# Raw model output: [0.14164813 0.1380289  0.14419188 0.14497547 0.14258242 0.14447217
#  0.14410096]
# Raw model output: [0.14175063 0.13798277 0.14388523 0.14488365 0.14269768 0.14453503
#  0.14426501]
# Raw model output: [0.14164439 0.13821518 0.14408833 0.14507614 0.14247492 0.14432715
#  0.14417395]
# Raw model output: [0.1417412  0.13796903 0.14384204 0.14506572 0.14256409 0.14428353
#  0.14453432]
# Raw model output: [0.14160286 0.13789095 0.14395373 0.14512274 0.14239316 0.14465417
#  0.14438237]
# Raw model output: [0.14191845 0.13801107 0.14406012 0.14478764 0.1426508  0.14445549
#  0.1441164 ]
# Raw model output: [0.1417891  0.13785467 0.1441233  0.14487328 0.14280935 0.1445692
#  0.14398102]
# Raw model output: [0.14179471 0.13787869 0.14413284 0.14501269 0.14265387 0.1444315
#  0.14409575]
# Raw model output: [0.14202991 0.13765992 0.14407781 0.14520629 0.14260375 0.14447375
#  0.14394854]
# Raw model output: [0.14204381 0.13760462 0.14396864 0.14533205 0.14232385 0.14462855
#  0.14409845]
# Raw model output: [0.14181645 0.1375571  0.14413534 0.1453972  0.1423805  0.14461254
#  0.14410077]
# Raw model output: [0.1416176  0.13756117 0.14421542 0.14556065 0.1424396  0.14464714
#  0.14395836]
# Raw model output: [0.14157796 0.13763744 0.14413688 0.14560023 0.14238489 0.14478177
#  0.14388092]
# Raw model output: [0.14154172 0.13758302 0.14413653 0.1454896  0.14239311 0.1447659
#  0.14409015]
# Raw model output: [0.14175925 0.13761027 0.1439491  0.14560369 0.14237976 0.14464545
#  0.14405252]
# Raw model output: [0.14169267 0.13759972 0.14401709 0.1455371  0.14230427 0.14488256
#  0.14396657]
# Raw model output: [0.14172399 0.13749976 0.144201   0.14556201 0.14238964 0.14467692
#  0.14394672]
# Raw model output: [0.14171357 0.13777675 0.14439961 0.14516576 0.14224489 0.14486036
#  0.14383897]
# Raw model output: [0.14168297 0.13768192 0.14431714 0.14521001 0.14210482 0.1450544
#  0.1439488 ]
# Raw model output: [0.14162959 0.13781638 0.14420813 0.14518005 0.14224252 0.14479838
#  0.14412497]
# Raw model output: [0.14138389 0.13785398 0.14437875 0.14523417 0.14227283 0.14497498
#  0.14390151]
# Raw model output: [0.14151722 0.13787012 0.14382276 0.14526346 0.14204542 0.14519842
#  0.14428261]
# Raw model output: [0.1415741  0.13769586 0.14427875 0.1454444  0.14222923 0.1449904
#  0.14378719]
# Raw model output: [0.14146836 0.13771623 0.14439061 0.14545879 0.14226688 0.14498322
#  0.14371592]
# Raw model output: [0.1416022  0.13782635 0.14415364 0.14539792 0.14230847 0.14478193
#  0.14392951]
# Raw model output: [0.14159957 0.13727498 0.14375937 0.14555496 0.14274564 0.1444788
#  0.14458668]
# Raw model output: [0.14185357 0.13717921 0.14371103 0.145471   0.1424848  0.14475256
#  0.1445478 ]
# Raw model output: [0.14186989 0.13746472 0.14382908 0.14544529 0.14267556 0.14433496
#  0.14438055]
# Raw model output: [0.14150533 0.1375469  0.14405762 0.14552881 0.14248629 0.14443088
#  0.14444414]
# Raw model output: [0.14161642 0.13753302 0.14382595 0.14558692 0.14233068 0.14456733
#  0.14453967]
# Raw model output: [0.14161563 0.1377085  0.14369372 0.14557423 0.14237401 0.144684
#  0.1443499 ]
# Raw model output: [0.14153247 0.13774917 0.14353919 0.14566149 0.14244024 0.14474574
#  0.14433166]
# Raw model output: [0.14162719 0.13801272 0.14352404 0.14553028 0.14250441 0.14455658
#  0.14424478]
# Raw model output: [0.14146769 0.13770276 0.1443345  0.14556946 0.14254197 0.14455582
#  0.1438278 ]
# Raw model output: [0.1415745  0.13761157 0.14417215 0.14537232 0.14257053 0.14475743
#  0.1439415 ]
# Raw model output: [0.14146574 0.13729611 0.14449851 0.14568295 0.14264056 0.14458911
#  0.14382711]
# Raw model output: [0.1416888  0.13748722 0.14426963 0.14527261 0.14242174 0.14486112
#  0.14399895]
# Raw model output: [0.14163361 0.137913   0.14430259 0.14518672 0.14229873 0.1448506
#  0.14381473]
# Raw model output: [0.14173695 0.13785096 0.14412872 0.14525762 0.14228792 0.14486562
#  0.14387217]
# Raw model output: [0.14155197 0.13754997 0.1441145  0.14513269 0.14227045 0.14515013
#  0.14423037]
# Raw model output: [0.14127086 0.13768259 0.1441719  0.14530404 0.14223933 0.14513388
#  0.14419743]
# Raw model output: [0.14122143 0.13808471 0.144311   0.14521657 0.14197028 0.14503993
#  0.1441561 ]
# Raw model output: [0.14132342 0.13816999 0.14417966 0.14551218 0.14202763 0.14464384
#  0.14414322]
# Raw model output: [0.14146362 0.13788229 0.14421996 0.1453838  0.14222187 0.14487498
#  0.14395358]
# Raw model output: [0.14150512 0.13797234 0.14428401 0.1453043  0.14222907 0.14477709
#  0.14392804]
# Raw model output: [0.14163159 0.1378272  0.14436078 0.14537928 0.14225826 0.14463341
#  0.14390948]
# Raw model output: [0.14143206 0.13798241 0.14411013 0.14539388 0.14214845 0.14488263
#  0.14405045]
# Raw model output: [0.14142922 0.13787554 0.14431347 0.14545596 0.14219874 0.14476122
#  0.14396586]
# Raw model output: [0.14152533 0.13790369 0.1440165  0.14543648 0.14227784 0.14482076
#  0.1440194 ]
# Raw model output: [0.14159201 0.1378958  0.14384805 0.14554161 0.14201783 0.14490516
#  0.14419954]
# Raw model output: [0.1416848  0.13795047 0.14376244 0.14552571 0.142133   0.14489248
#  0.14405115]
# Raw model output: [0.14181337 0.13802963 0.14375533 0.1454246  0.14216167 0.14475216
#  0.14406326]
# Raw model output: [0.1416065  0.13800535 0.1437889  0.14547604 0.1421969  0.14482091
#  0.14410542]
# Raw model output: [0.14159071 0.137843   0.14372537 0.14556485 0.14221819 0.14480709
#  0.14425083]
# Raw model output: [0.14160231 0.13786088 0.1439035  0.14537635 0.14216541 0.14490892
#  0.1441826 ]
# Raw model output: [0.14162455 0.13780922 0.1438033  0.1454016  0.1421892  0.14498161
#  0.14419055]
# Raw model output: [0.14146122 0.13782822 0.14385886 0.1455657  0.14220893 0.14493534
#  0.14414181]
# Raw model output: [0.14147477 0.13789764 0.14372796 0.14540797 0.14228949 0.14499432
#  0.14420792]
# Raw model output: [0.14136662 0.13788751 0.14368403 0.14548124 0.14242314 0.14495537
#  0.14420214]
# Raw model output: [0.14172947 0.1380306  0.14356528 0.14539571 0.14237376 0.1448067
#  0.14409843]
# Raw model output: [0.14207166 0.13795435 0.14364024 0.14542903 0.14224973 0.14466995
#  0.14398506]
# Raw model output: [0.14160633 0.13782093 0.14366253 0.14541148 0.14221758 0.14497976
#  0.14430141]
# Raw model output: [0.14163421 0.13784976 0.14347188 0.1454078  0.14217862 0.1451498
#  0.14430797]
# Raw model output: [0.14173527 0.13806932 0.14352736 0.14529888 0.14214925 0.14507332
#  0.14414658]
# Raw model output: [0.14145586 0.13819958 0.14375794 0.14523734 0.14218368 0.14510755
#  0.14405812]
# Raw model output: [0.14131272 0.13832454 0.14404394 0.14516878 0.1421207  0.14504714
#  0.14398219]
# Raw model output: [0.14125139 0.1383208  0.14400268 0.14534296 0.14232054 0.14484213
#  0.14391951]
# Raw model output: [0.14126223 0.13810904 0.14395466 0.1453104  0.14234695 0.14492738
#  0.14408933]
# Raw model output: [0.14150532 0.13825198 0.14417107 0.14525887 0.14215508 0.14457744
#  0.14408028]
# Raw model output: [0.14149883 0.13809025 0.14378643 0.14548986 0.14233842 0.14486924
#  0.14392689]
# Raw model output: [0.14183685 0.13799287 0.14383969 0.14542858 0.14227925 0.14479387
#  0.14382891]
# Raw model output: [0.14183964 0.13804486 0.14401262 0.14511052 0.14237317 0.14471024
#  0.14390892]
# Raw model output: [0.14184454 0.13789706 0.14384545 0.14527927 0.14215784 0.14486821
#  0.14410758]
# Raw model output: [0.14190483 0.13788044 0.14379174 0.14537303 0.14225347 0.14470956
#  0.14408696]
# Raw model output: [0.14215086 0.13798355 0.14395687 0.14500028 0.14235434 0.14463075
#  0.14392334]
# Raw model output: [0.14204235 0.13818757 0.14393409 0.14488825 0.14231408 0.14443944
#  0.14419423]
# Raw model output: [0.14186478 0.13823746 0.1440122  0.14501132 0.14233594 0.14456268
#  0.14397557]
# Raw model output: [0.14176093 0.13801922 0.14396138 0.14539444 0.14215028 0.14473596
#  0.14397778]
# Raw model output: [0.14186548 0.13821521 0.14407474 0.14513454 0.14226341 0.14462346
#  0.14382316]
# Raw model output: [0.14163838 0.13826728 0.14396748 0.14515267 0.14230107 0.14472537
#  0.14394778]
# Raw model output: [0.14174661 0.1381345  0.14393611 0.14502043 0.1423636  0.1447847
#  0.14401412]
# Raw model output: [0.14170802 0.13807875 0.14381826 0.14518395 0.1423365  0.14484088
#  0.1440336 ]
# Raw model output: [0.14191608 0.13800661 0.1437381  0.1451335  0.1423302  0.1447808
#  0.1440947 ]
# Raw model output: [0.14201805 0.13795635 0.14375275 0.14513148 0.14229164 0.14474879
#  0.14410092]
# Raw model output: [0.1420181  0.13800709 0.14363173 0.14524578 0.14235345 0.14468138
#  0.14406252]
# Raw model output: [0.14209762 0.13801403 0.1436994  0.14503324 0.14228955 0.14473046
#  0.1441357 ]
# Raw model output: [0.14215368 0.13785022 0.14386563 0.1451399  0.14232083 0.14465702
#  0.1440127 ]
# Raw model output: [0.14200337 0.13805535 0.14391688 0.14516339 0.1422013  0.14469531
#  0.1439644 ]
# Raw model output: [0.14194916 0.13756646 0.14390509 0.14554743 0.14205691 0.14459585
#  0.1443791 ]
# Raw model output: [0.1423927  0.13756697 0.14343904 0.14555757 0.14184646 0.14469849
#  0.14449885]
# Raw model output: [0.14238055 0.13760906 0.14334099 0.1456706  0.14175245 0.14482652
#  0.14441979]
# Raw model output: [0.14218335 0.13781928 0.14336455 0.14563578 0.14196765 0.14468592
#  0.1443434 ]
# Raw model output: [0.14170842 0.1380279  0.14409636 0.1451348  0.14227451 0.14467219
#  0.14408585]
# Raw model output: [0.1415196  0.13816519 0.144205   0.1451312  0.142103   0.14471588
#  0.14416018]
# Raw model output: [0.14163588 0.13814062 0.14411615 0.14481607 0.14216267 0.14487737
#  0.14425126]
# Raw model output: [0.14168693 0.13807121 0.14405587 0.14498957 0.14228943 0.14480451
#  0.14410244]
# Raw model output: [0.1418745  0.13814965 0.1439245  0.1452285  0.14232463 0.14459793
#  0.1439002 ]
# Raw model output: [0.14188187 0.13784541 0.14403695 0.1454665  0.14211494 0.1446071
#  0.14404719]
# Raw model output: [0.14192232 0.13764091 0.14355735 0.14590526 0.14219451 0.14474946
#  0.14403018]
# Raw model output: [0.14218125 0.13758954 0.143512   0.14566723 0.14209655 0.14446597
#  0.1444875 ]
# Raw model output: [0.14240368 0.13786805 0.14315003 0.1458916  0.14209218 0.14443482
#  0.14415966]
# Raw model output: [0.1422915  0.13790828 0.14327794 0.14557871 0.14201851 0.14445087
#  0.14447418]
# Raw model output: [0.14194411 0.13805766 0.14321443 0.14545865 0.14226198 0.14452553
#  0.14453764]
# Raw model output: [0.14196417 0.13811845 0.14316773 0.14557567 0.1423133  0.14457083
#  0.14428985]
# Raw model output: [0.14204487 0.13799395 0.14312012 0.14585464 0.14222114 0.14451984
#  0.14424549]
# Raw model output: [0.14211217 0.13790706 0.1433042  0.14578223 0.14191754 0.14449343
#  0.14448334]
# Raw model output: [0.14184575 0.13797328 0.14329806 0.14590184 0.14228192 0.14441377
#  0.14428537]
# Raw model output: [0.14177875 0.13797374 0.14353256 0.14569221 0.14218138 0.14433394
#  0.14450747]
# Raw model output: [0.14176346 0.13797885 0.14333445 0.14543848 0.14219339 0.14471725
#  0.1445741 ]
# Raw model output: [0.14183488 0.13820928 0.14347461 0.14528678 0.14239088 0.1443337
#  0.14446984]
# Raw model output: [0.14140676 0.13776527 0.14367627 0.14554352 0.14199035 0.14463228
#  0.14498551]
# Raw model output: [0.1421124  0.13755801 0.14315017 0.14569375 0.14248995 0.14429703
#  0.14469865]
# Raw model output: [0.14198798 0.13784982 0.14308363 0.14545082 0.14287733 0.14446363
#  0.14428675]
# Raw model output: [0.14161292 0.13774489 0.14358956 0.14545943 0.14242065 0.14449947
#  0.14467305]
# Raw model output: [0.14165667 0.13785675 0.14358406 0.14552113 0.14258377 0.14440978
#  0.1443879 ]
# Raw model output: [0.1415248  0.13781852 0.14351338 0.14560549 0.14235938 0.14467585
#  0.14450264]
# Raw model output: [0.14187369 0.13777918 0.14361209 0.14556095 0.14247248 0.14445563
#  0.14424594]
# Raw model output: [0.14177635 0.13749641 0.14353411 0.14579767 0.1421946  0.14467627
#  0.14452453]
# Raw model output: [0.14177878 0.13738051 0.14337759 0.14567588 0.1421584  0.1450051
#  0.14462377]
# ...
# Raw model output: [0.14223215 0.13988331 0.14350438 0.14439751 0.14254978 0.14396204
#  0.14347087]
# Raw model output: [0.14210044 0.13983835 0.14374042 0.14443447 0.14227144 0.14388375
#  0.14373115]
# Raw model output: [0.14226809 0.13989407 0.1437237  0.14436045 0.14227612 0.14399742
#  0.14348017]
# Raw model output: [0.14228165 0.13987672 0.14356492 0.14429952 0.1422705  0.1441301
#  0.14357653]
# Raw model output: [0.1423054  0.13996653 0.14371845 0.14439437 0.14235568 0.1438353
#  0.14342432]
# Raw model output: [0.14247672 0.13985863 0.14357148 0.14435118 0.14240949 0.14396277
#  0.14336963]
# Raw model output: [0.14251469 0.13977472 0.14356108 0.14438353 0.14231716 0.14400542
#  0.14344336]
# Raw model output: [0.1424929  0.13982143 0.14361526 0.14444613 0.1423191  0.14394262
#  0.14336245]
# Raw model output: [0.14249675 0.13987847 0.14359124 0.14434837 0.1424515  0.14393257
#  0.14330113]
# Raw model output: [0.14248227 0.13990337 0.14354767 0.14418922 0.14240941 0.14404593
#  0.14342214]
# Raw model output: [0.14235719 0.13993098 0.14357263 0.1443586  0.14221966 0.14402698
#  0.14353399]
# Raw model output: [0.14242688 0.13971145 0.14350794 0.14434415 0.14240088 0.14393412
#  0.14367452]
# Raw model output: [0.14242265 0.13969018 0.14343496 0.14426719 0.14215231 0.14415848
#  0.14387424]
# Raw model output: [0.14246462 0.13975202 0.14339739 0.14440393 0.14216954 0.1439499
#  0.14386263]
# Raw model output: [0.14233744 0.13962145 0.14353833 0.14436208 0.14217213 0.14419454
#  0.14377399]
# Raw model output: [0.14219445 0.13955031 0.14365608 0.14406781 0.14193773 0.14440235
#  0.14419125]
# Raw model output: [0.14192955 0.13985187 0.1435103  0.14401187 0.14246117 0.14382295
#  0.1444123 ]
# Raw model output: [0.1420953  0.13909855 0.14351162 0.14455664 0.142238   0.1438821
#  0.14461778]
# Raw model output: [0.14222224 0.13893385 0.1434964  0.14473234 0.14210787 0.14399418
#  0.1445131 ]
# Raw model output: [0.14232494 0.13895269 0.14323078 0.14460333 0.14234123 0.14416233
#  0.14438476]
# Raw model output: [0.14202428 0.1391838  0.14344817 0.14472277 0.1421302  0.14426923
#  0.14422157]
# Raw model output: [0.1416827  0.13930623 0.14352037 0.14465757 0.14226605 0.14471655
#  0.14385049]
# Raw model output: [0.14172228 0.13916577 0.1433719  0.14484324 0.14248176 0.14404625
#  0.14436881]
# Raw model output: [0.14178616 0.13921301 0.1435868  0.14456102 0.14237319 0.14451113
#  0.14396866]
# Raw model output: [0.14175554 0.13926911 0.14356351 0.1444298  0.14249165 0.14438166
#  0.14410877]
# Raw model output: [0.14175995 0.13925262 0.14364782 0.1445008  0.14239997 0.14424545
#  0.14419343]
# Raw model output: [0.14173606 0.13934909 0.1435717  0.14459564 0.14242148 0.14412512
#  0.14420082]
# Raw model output: [0.14176227 0.13934839 0.14341931 0.14463243 0.14236574 0.14410147
#  0.14437042]
# Raw model output: [0.14159696 0.13932644 0.14341322 0.14470428 0.14236423 0.14428316
#  0.14431168]
# Raw model output: [0.14176616 0.13950962 0.14301887 0.1446395  0.1426068  0.14385821
#  0.14460078]
# Raw model output: [0.14205769 0.13931738 0.14278185 0.14462967 0.14263394 0.14390956
#  0.1446699 ]
# Raw model output: [0.14204587 0.13948406 0.14288215 0.14456643 0.14252135 0.14392707
#  0.1445731 ]
# Raw model output: [0.14234641 0.13937247 0.14280552 0.14463688 0.14248075 0.14387001
#  0.14448793]
# Raw model output: [0.14244425 0.139531   0.14304186 0.14437832 0.14252934 0.14390384
#  0.1441714 ]
# Raw model output: [0.14189716 0.13948494 0.14305992 0.14454219 0.14217454 0.14421822
#  0.14462306]
# Raw model output: [0.14160323 0.13971084 0.14334318 0.14457302 0.1423927  0.14432874
#  0.14404826]
# Raw model output: [0.14177115 0.1392055  0.14296176 0.14473756 0.1423114  0.14497036
#  0.14404221]
# Raw model output: [0.14220697 0.13922516 0.14349265 0.144483   0.14235155 0.14458208
#  0.14365855]
# Raw model output: [0.14218901 0.13911663 0.14340223 0.14478032 0.14208096 0.14470471
#  0.14372614]
# Raw model output: [0.14194335 0.13897973 0.14363112 0.1450794  0.1417222  0.14483525
#  0.14380893]
# Raw model output: [0.14199437 0.13895077 0.14346911 0.14501803 0.14176229 0.14497618
#  0.14382921]
# Raw model output: [0.14189972 0.13886376 0.14394301 0.14483479 0.14173739 0.14495699
#  0.14376442]
# Raw model output: [0.14207645 0.13855524 0.14397486 0.14501655 0.14178038 0.14485735
#  0.14373915]
# Raw model output: [0.14206533 0.13872074 0.14377704 0.14493838 0.14202344 0.14462113
#  0.14385393]
# Raw model output: [0.1419696  0.1386983  0.14408627 0.14467475 0.1420081  0.14482614
#  0.14373685]
# Raw model output: [0.14185974 0.13852426 0.1437495  0.14474018 0.14221627 0.14516072
#  0.14374928]
# Raw model output: [0.14155269 0.1388134  0.14285673 0.14540178 0.14200239 0.14506006
#  0.14431289]
# Raw model output: [0.14178492 0.13920799 0.14325792 0.1449504  0.14218195 0.14434195
#  0.14427486]
# Raw model output: [0.14220802 0.13912636 0.14313702 0.14502141 0.14187594 0.14381373
#  0.14481755]
# Raw model output: [0.1418405  0.13953033 0.1433492  0.14502591 0.14179632 0.14365683
#  0.14480089]
# Raw model output: [0.14195481 0.13942672 0.14355157 0.1445874  0.14198592 0.14407486
#  0.14441869]
# Raw model output: [0.14184576 0.1398215  0.14375995 0.14432688 0.14216201 0.1439852
#  0.1440987 ]
# Raw model output: [0.14182888 0.13984333 0.14375757 0.14423239 0.14214519 0.14424075
#  0.14395183]
# Raw model output: [0.14216085 0.13960685 0.14339112 0.14445846 0.14221601 0.14421172
#  0.14395502]
# Raw model output: [0.14223307 0.13985501 0.14359918 0.14427607 0.14224356 0.14403099
#  0.14376208]
# Raw model output: [0.1421205  0.13978004 0.14367917 0.14437595 0.14221217 0.14394562
#  0.14388649]
# Raw model output: [0.1423629  0.1399021  0.14347857 0.1442395  0.14219756 0.14391975
#  0.1438996 ]
# Raw model output: [0.14225303 0.13998412 0.14357173 0.14419375 0.14213337 0.14396963
#  0.14389439]
# Raw model output: [0.14241223 0.13991229 0.14322522 0.14414375 0.14230567 0.14419696
#  0.14380383]
# Raw model output: [0.14238149 0.14002913 0.1433366  0.14405577 0.14227849 0.14405164
#  0.1438669 ]
# Raw model output: [0.14228627 0.14007062 0.14340344 0.14414276 0.14227681 0.1439908
#  0.14382929]
# Raw model output: [0.14225689 0.13998121 0.14333016 0.14405787 0.14252801 0.14411819
#  0.14372769]
# Raw model output: [0.1423616  0.140017   0.14328563 0.14408885 0.14235777 0.14409107
#  0.1437981 ]
# Raw model output: [0.14237565 0.13991986 0.14335842 0.14423776 0.14228426 0.14405407
#  0.14377004]
# Raw model output: [0.14205123 0.13992594 0.14352156 0.14414716 0.14245519 0.14412914
#  0.14376976]
# Raw model output: [0.14185607 0.1399828  0.14356507 0.1443065  0.1424068  0.14412192
#  0.14376093]
# Raw model output: [0.14214398 0.13985935 0.1433897  0.1443896  0.14236824 0.14392312
#  0.14392607]
# Raw model output: [0.14187135 0.13984355 0.14356822 0.14428139 0.14243522 0.14386795
#  0.14413229]
# Raw model output: [0.14175683 0.14025635 0.14347796 0.14417739 0.14226922 0.14382505
#  0.14423713]
# Raw model output: [0.14123541 0.140263   0.14371593 0.1446137  0.14221461 0.14382368
#  0.14413367]
# Raw model output: [0.14116341 0.14042172 0.14391114 0.14437264 0.1421695  0.14384878
#  0.1441128 ]
# Raw model output: [0.14227208 0.1398124  0.14349855 0.14434707 0.14243871 0.1441342
#  0.14349693]
# Raw model output: [0.14210011 0.13984957 0.14347668 0.14434935 0.14225678 0.14418955
#  0.14377792]
# Raw model output: [0.14215198 0.13992739 0.14360093 0.1443177  0.14232786 0.14411421
#  0.14356002]
# Raw model output: [0.1422592  0.14000091 0.14338605 0.14436384 0.14244306 0.14395444
#  0.14359249]
# Raw model output: [0.14215623 0.1402874  0.14326526 0.1441969  0.14251174 0.14390956
#  0.14367302]
# Raw model output: [0.14216016 0.14049567 0.14322628 0.14420365 0.14257963 0.14385855
#  0.14347608]
# Raw model output: [0.14230645 0.14029557 0.14327507 0.14418572 0.14253105 0.14383776
#  0.14356835]
# Raw model output: [0.1423635  0.14006838 0.14351304 0.14430617 0.14239931 0.1439068
#  0.14344281]
# Raw model output: [0.14235003 0.140184   0.14333914 0.14425077 0.14247894 0.14381601
#  0.14358112]
# Raw model output: [0.14239727 0.14028211 0.14334689 0.14431031 0.14232123 0.14375654
#  0.1435857 ]
# Raw model output: [0.14246415 0.14008331 0.14345047 0.14418916 0.14241205 0.14385895
#  0.143542  ]
# Raw model output: [0.14256844 0.14016676 0.1431312  0.14421232 0.14224975 0.14391859
#  0.14375295]
# Raw model output: [0.14237888 0.14026718 0.14330362 0.14426129 0.14237496 0.14387299
#  0.14354107]
# Raw model output: [0.14251897 0.14005016 0.14337796 0.14432505 0.14232016 0.14378572
#  0.14362198]
# Raw model output: [0.14249618 0.14022982 0.14345667 0.14428245 0.14233921 0.14377871
#  0.14341697]
# Raw model output: [0.14257725 0.13990752 0.14343202 0.14445814 0.14223479 0.14380531
#  0.143585  ]
# Raw model output: [0.14231452 0.1399712  0.1434374  0.14433953 0.14220375 0.14407426
#  0.14365931]
# Raw model output: [0.14234793 0.14005633 0.1434889  0.14436418 0.14233297 0.14387156
#  0.14353812]
# Raw model output: [0.14255093 0.14009507 0.14367108 0.14433175 0.14239848 0.1435747
#  0.1433779 ]
# Raw model output: [0.14237754 0.14014071 0.14359136 0.14434302 0.14247507 0.14382534
#  0.14324696]
# Raw model output: [0.14236788 0.14013124 0.1436334  0.14418596 0.1423429  0.14393117
#  0.1434075 ]
# Raw model output: [0.1424631  0.13999584 0.14355132 0.14440173 0.14235365 0.14375104
#  0.1434833 ]
# Raw model output: [0.14260364 0.14003515 0.14329009 0.14429948 0.14244395 0.14375378
#  0.14357385]
# Raw model output: [0.14241055 0.13997872 0.14333889 0.14421365 0.14241995 0.14410971
#  0.14352854]
# Raw model output: [0.1422201  0.14008549 0.14321364 0.14418694 0.14260764 0.1441733
#  0.14351293]
# Raw model output: [0.14168064 0.14026135 0.14291102 0.14456336 0.1428837  0.14392759
#  0.14377241]
# Raw model output: [0.14159401 0.14014564 0.14307429 0.14451224 0.14294899 0.14389515
#  0.14382969]
# Raw model output: [0.14164248 0.14012833 0.14272515 0.14443733 0.14254835 0.14430438
#  0.14421402]
# Raw model output: [0.14184089 0.14002162 0.14293143 0.14425845 0.14253297 0.14436097
#  0.14405361]
# Raw model output: [0.14170858 0.1401094  0.14297609 0.14444551 0.14285284 0.14414406
#  0.1437636 ]
# Raw model output: [0.14201619 0.1399314  0.14289936 0.14443338 0.1428546  0.14424612
#  0.14361894]
# Raw model output: [0.1420303  0.13997664 0.14331786 0.1443645  0.14228092 0.14439777
#  0.14363205]
# Raw model output: [0.14220001 0.1400712  0.14316061 0.1441398  0.14250244 0.14426781
#  0.14365816]
# Raw model output: [0.14231199 0.14019302 0.14334641 0.14407077 0.14243513 0.14406236
#  0.14358032]
# Raw model output: [0.14235735 0.14008783 0.14321122 0.14456102 0.14227399 0.14395885
#  0.14354979]
# Raw model output: [0.14249055 0.14020543 0.14323634 0.1443523  0.14216691 0.14384873
#  0.14369969]
# Raw model output: [0.14238743 0.14019807 0.14341746 0.14445165 0.14220557 0.14375396
#  0.14358588]
# Raw model output: [0.14245827 0.14016752 0.14346626 0.1444342  0.14216284 0.14371051
#  0.1436004 ]
# Raw model output: [0.14245752 0.14030872 0.14349326 0.14434883 0.14227727 0.14364673
#  0.14346774]
# Raw model output: [0.14246067 0.14018296 0.14357176 0.1443121  0.14226148 0.14368522
#  0.14352584]
# Raw model output: [0.142421   0.14022529 0.14361075 0.14432327 0.1422113  0.1437087
#  0.14349966]
# Raw model output: [0.14246352 0.14037637 0.14332287 0.14435008 0.1423821  0.14357841
#  0.1435267 ]
# Raw model output: [0.1424963  0.1400815  0.14334324 0.14457278 0.14224495 0.1436468
#  0.14361446]
# Raw model output: [0.14240196 0.13972946 0.14338925 0.14461377 0.14207625 0.14402866
#  0.14376058]
# Raw model output: [0.14232852 0.13951379 0.14348572 0.14487192 0.14210233 0.1440087
#  0.14368899]
# Raw model output: [0.14224999 0.13928822 0.14323826 0.1449934  0.14202005 0.14427932
#  0.14393073]
# Raw model output: [0.14262171 0.13928224 0.14343919 0.14482881 0.14201735 0.14406528
#  0.14374545]
# Raw model output: [0.14231995 0.13936669 0.14364713 0.14494947 0.14202867 0.14403695
#  0.14365114]
# Raw model output: [0.14212166 0.13920459 0.14357404 0.14483117 0.14193626 0.14439508
#  0.14393722]
# Raw model output: [0.14204776 0.13909495 0.14355728 0.1450542  0.14203782 0.14436875
#  0.14383915]
# Raw model output: [0.1420216  0.1390437  0.1436319  0.14506705 0.14192294 0.14440317
#  0.14390956]
# Raw model output: [0.14202774 0.13904633 0.1437847  0.14482637 0.14210075 0.14435071
#  0.1438634 ]
# Raw model output: [0.14194426 0.13923983 0.14382009 0.14471704 0.14203744 0.14435974
#  0.14388165]
# Raw model output: [0.14229354 0.13916092 0.14360288 0.14486587 0.14219259 0.14422923
#  0.14365502]
# Raw model output: [0.14224775 0.13909908 0.14378428 0.14482597 0.14210576 0.1442152
#  0.143722  ]
# Raw model output: [0.14200415 0.1391339  0.14369226 0.14488511 0.14229618 0.14430527
#  0.14368315]
# Raw model output: [0.14210685 0.13906589 0.14373663 0.14477073 0.14206937 0.1444867
#  0.1437638 ]
# Raw model output: [0.14202006 0.13907371 0.14398783 0.14476806 0.14212817 0.1441202
#  0.14390194]
# Raw model output: [0.14209166 0.13924019 0.14402954 0.1446247  0.1421863  0.14435747
#  0.14347014]
# Raw model output: [0.14207697 0.13927731 0.1436072  0.14483461 0.14225915 0.14410141
#  0.14384337]
# Raw model output: [0.1422529  0.13923341 0.14372413 0.14497487 0.14234777 0.1438141
#  0.1436528 ]
# Raw model output: [0.14207053 0.13921061 0.14379688 0.1447813  0.14205094 0.14399584
#  0.14409396]
# Raw model output: [0.14201474 0.13930467 0.14375825 0.14495368 0.1422917  0.14382719
#  0.14384972]
# Raw model output: [0.14200518 0.13928613 0.14366432 0.14495319 0.14215598 0.14391355
#  0.14402165]
# Raw model output: [0.14199534 0.13913468 0.14371589 0.14487849 0.14225207 0.14401546
#  0.14400809]
# Raw model output: [0.14187862 0.13902353 0.14357333 0.14473577 0.14231634 0.14410509
#  0.14436737]
# Raw model output: [0.14203216 0.13896623 0.14358711 0.1447736  0.14231297 0.14402069
#  0.14430718]
# Raw model output: [0.14227891 0.13915631 0.14362523 0.14474656 0.14236595 0.14377572
#  0.14405134]
# Raw model output: [0.14199944 0.13932681 0.14370689 0.14486809 0.14237869 0.14373428
#  0.14398584]
# Raw model output: [0.1423211  0.13917911 0.14375426 0.1445957  0.14224198 0.14387025
#  0.14403763]
# Raw model output: [0.14223504 0.13906941 0.14360872 0.14473127 0.1422414  0.14394361
#  0.14417054]
# Raw model output: [0.14226606 0.13912566 0.14360428 0.14460567 0.1422137  0.14395891
#  0.14422566]
# Raw model output: [0.14213231 0.13937232 0.14367262 0.14464794 0.14221391 0.14403889
#  0.143922  ]
# Raw model output: [0.1421268  0.13932113 0.14372575 0.14473487 0.14238222 0.14391534
#  0.1437939 ]
# Raw model output: [0.1421754  0.13908221 0.14354251 0.14489903 0.14210613 0.14416806
#  0.14402667]
# Raw model output: [0.14220941 0.13943039 0.1435219  0.1447628  0.14202653 0.14401901
#  0.14402996]
# Raw model output: [0.14230865 0.13945766 0.14323325 0.14484444 0.14206345 0.14407006
#  0.14402245]
# Raw model output: [0.14230369 0.13967119 0.14334388 0.1449713  0.14185904 0.1439748
#  0.14387612]
# Raw model output: [0.14225186 0.13961326 0.14326249 0.14504363 0.14200406 0.14404313
#  0.14378157]
# Raw model output: [0.14222895 0.13946007 0.14311612 0.14519632 0.14176944 0.14406271
#  0.14416638]
# Raw model output: [0.14202353 0.13943572 0.14357881 0.14515243 0.14199653 0.14398517
#  0.14382769]
# Raw model output: [0.14209999 0.13942246 0.1434315  0.1451005  0.14189236 0.14408043
#  0.14397283]
# Raw model output: [0.14202183 0.1395303  0.143439   0.14506301 0.14196429 0.14406696
#  0.14391454]
# Raw model output: [0.1419206  0.13949433 0.14346896 0.14508331 0.14196825 0.14397728
#  0.14408727]
# Raw model output: [0.14202264 0.13956937 0.14330423 0.1447583  0.14214201 0.14406158
#  0.14414185]
# Raw model output: [0.14193046 0.13941635 0.14339131 0.14499001 0.14213715 0.14397469
#  0.1441601 ]
# Raw model output: [0.14189495 0.13933013 0.1435036  0.14498803 0.14206372 0.14412253
#  0.14409709]
# Raw model output: [0.14205535 0.13929358 0.14346567 0.14495279 0.14216131 0.14402042
#  0.1440509 ]
# Raw model output: [0.14194289 0.13941786 0.1432733  0.1450113  0.1422449  0.14412588
#  0.14398396]
# The Kernel crashed while executing code in the current cell or a previous cell.
#
# Please review the code in the cell(s) to identify a possible cause of the failure.
#
# Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
